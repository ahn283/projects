# %% [markdown]
# # Get global stock data

# %% [markdown]
# ## collect tickers

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import math
import pandas as pd

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
url = 'https://www.investing.com/stock-screener/?sp=country::5|sector::a|industry::a|equityType::a%3Ceq_market_cap;1'
# open url
driver.get(url)

# %%
# HTML 정보에 해당하는 driver.page_source를 BeautifulSoup 객체로 만들어준다.
# make BeautifulSoup object from driver.page_source 
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
# country
html.find(class_='js-search-input inputDropDown')['value']
# Out:
# 'United States'

# %%
html_table = html.select('table.genTbl.openTbl.resultsStockScreenerTbl.elpTbl')
print(html_table[0])
# Out:
# <table class="genTbl openTbl resultsStockScreenerTbl elpTbl" id="resultsTable">
# <thead>
# <tr>
# <th class="flag"> </th>
# <th class="symbol left js-sortable pointer" data-column-name="name_trans"><i title="Name">Name</i><span class="headerSortDefault"></span></th><th class="left js-sortable pointer" data-column-name="viewData.symbol"><i title="Symbol">Symbol</i><span class="headerSortDefault"></span></th><th class="left displayNone js-sortable pointer" data-column-name="exchange_trans"><i title="Exchange">Exchange</i><span class="headerSortDefault"></span></th><th class="left displayNone js-sortable pointer" data-column-name="sector_trans"><i title="Sector">Sector</i><span class="headerSortDefault"></span></th><th class="left displayNone js-sortable pointer" data-column-name="industry_trans"><i title="Industry">Industry</i><span class="headerSortDefault"></span></th><th class="js-sortable pointer" data-column-name="last"><i title="Last">Last</i><span class="headerSortDefault"></span></th><th class="js-sortable pointer" data-column-name="pair_change_percent"><i title="Chg. %">Chg. %</i><span class="headerSortDefault"></span></th><th class="js-sortable pointer" data-column-name="eq_market_cap"><i title="Market Cap">Market Cap</i><span class="headerSortDown"></span></th><th class="js-sortable pointer" data-column-name="turnover_volume"><i title="Vol.">Vol.</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="eq_pe_ratio"><i title="P/E Ratio">P/E Ratio</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="MACD"><i title="MACD (12,26 / 1D)">MACD (12,26 / 1D)</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="eq_revenue"><i title="Revenue">Revenue</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="avg_volume"><i title="Average Vol. (3m)">Average Vol. (3m)</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="eq_eps"><i title="EPS">EPS</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="eq_beta"><i title="Beta">Beta</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="eq_dividend"><i title="Dividend">Dividend</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="eq_yield"><i title="Yield">Yield</i><span class="headerSortDefault"></span></th><th class="left displayNone js-sortable pointer" data-column-name="tech_sum_900"><i title="15 Minutes">15 Minutes</i><span class="headerSortDefault"></span></th><th class="left displayNone js-sortable pointer" data-column-name="tech_sum_3600"><i title="Hourly">Hourly</i><span class="headerSortDefault"></span></th><th class="left displayNone js-sortable pointer" data-column-name="tech_sum_86400"><i title="Daily">Daily</i><span class="headerSortDefault"></span></th><th class="left displayNone js-sortable pointer" data-column-name="tech_sum_week"><i title="Weekly">Weekly</i><span class="headerSortDefault"></span></th><th class="left displayNone js-sortable pointer" data-column-name="tech_sum_month"><i title="Monthly">Monthly</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="daily"><i title="Daily">Daily</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="week"><i title="1 Week">1 Week</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="month"><i title="1 Month">1 Month</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="ytd"><i title="YTD">YTD</i><span class="headerSortDefault"></span></th><th class="displayNone js-sortable pointer" data-column-name="year"><i title="1 Year">1 Year</i><span class="headerSortDefault"></span></th><th class="displayNone js- ...
# <script>
# 	var columnsSettings_stock_screener = new ColumnsSettings(
# 		'ltr',																	   // strHtmlDir
# 		'resultsContainer',															 	   // containerId
# 		'resultsContainer',															   	   // tab
# 		'stock_screener',																		   // id
# 		'Currently selected: X (max 8)', // message
# 		'8',															   // intMaxCheckboxes
# 		'1'                                                          // intMinOptCheckboxes
# 	);
# </script>
# <div class="colSelectIconWrapper">
# <span class="colSelectIcon" id="colSelectIcon_stock_screener" onclick="columnsSettings_stock_screener.colSelectIconClick(event);">
# </span>
# </div>
# <form class="colSelectForm" id="resultsContainerColsSelectstock_screener">
# <div class="tooltipPopup displayNone colSelectPopup js-column-select-popup" id="colSelectPopup_stock_screener">
# <div class="header">
# Adjust table </div>
# <div class="content">
# <div class="smallPopupRows">
# <ul>
# <li>
# <input checked="true" data-column-name="name_trans" data-required="1" id="SS_1" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="name_trans"/>
# <label class="pointer" for="SS_1" title="Name">
# Name </label>
# </li>
# <li>
# <input checked="true" data-column-name="viewData.symbol" data-required="1" id="SS_2" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="viewData.symbol"/>
# <label class="pointer" for="SS_2" title="Symbol">
# Symbol </label>
# </li>
# <li>
# <input data-column-name="exchange_trans" id="SS_3" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="exchange_trans"/>
# <label class="pointer" for="SS_3" title="Exchange">
# Exchange </label>
# </li>
# <li>
# <input data-column-name="sector_trans" id="SS_4" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="sector_trans"/>
# <label class="pointer" for="SS_4" title="Sector">
# Sector </label>
# </li>
# <li>
# <input data-column-name="industry_trans" id="SS_5" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="industry_trans"/>
# <label class="pointer" for="SS_5" title="Industry">
# Industry </label>
# </li>
# <li>
# <input checked="true" data-column-name="last" id="SS_6" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="last"/>
# <label class="pointer" for="SS_6" title="Last">
# Last </label>
# </li>
# <li>
# <input checked="true" data-column-name="pair_change_percent" id="SS_7" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="pair_change_percent"/>
# <label class="pointer" for="SS_7" title="Chg. %">
# Chg. % </label>
# </li>
# <li>
# <input checked="true" data-column-name="eq_market_cap" id="SS_8" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="eq_market_cap"/>
# <label class="pointer" for="SS_8" title="Market Cap">
# Market Cap </label>
# </li>
# <li>
# <input checked="true" data-column-name="turnover_volume" id="SS_9" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="turnover_volume"/>
# <label class="pointer" for="SS_9" title="Vol.">
# Vol. </label>
# </li>
# <li>
# <input data-column-name="eq_pe_ratio" id="SS_10" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="eq_pe_ratio"/>
# <label class="pointer" for="SS_10" title="P/E Ratio">
# P/E Ratio </label>
# </li>
# <li>
# <input data-column-name="MACD" id="SS_11" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="MACD"/>
# <label class="pointer" for="SS_11" title="MACD (12,26 / 1D)">
# MACD (12,26 / 1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="eq_revenue" id="SS_12" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="eq_revenue"/>
# <label class="pointer" for="SS_12" title="Revenue">
# Revenue </label>
# </li>
# <li class="displayNone">
# <input data-column-name="avg_volume" id="SS_13" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="avg_volume"/>
# <label class="pointer" for="SS_13" title="Average Vol. (3m)">
# Average Vol. (3m) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="eq_eps" id="SS_14" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="eq_eps"/>
# <label class="pointer" for="SS_14" title="EPS">
# EPS </label>
# </li>
# <li class="displayNone">
# <input data-column-name="eq_beta" id="SS_15" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="eq_beta"/>
# <label class="pointer" for="SS_15" title="Beta">
# Beta </label>
# </li>
# <li class="displayNone">
# <input data-column-name="eq_dividend" id="SS_16" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="eq_dividend"/>
# <label class="pointer" for="SS_16" title="Dividend">
# Dividend </label>
# </li>
# <li class="displayNone">
# <input data-column-name="eq_yield" id="SS_17" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="eq_yield"/>
# <label class="pointer" for="SS_17" title="Yield">
# Yield </label>
# </li>
# <li class="displayNone">
# <input data-column-name="tech_sum_900" id="SS_18" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="tech_sum_900"/>
# <label class="pointer" for="SS_18" title="15 Minutes">
# 15 Minutes </label>
# </li>
# <li class="displayNone">
# <input data-column-name="tech_sum_3600" id="SS_19" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="tech_sum_3600"/>
# <label class="pointer" for="SS_19" title="Hourly">
# Hourly </label>
# </li>
# <li class="displayNone">
# <input data-column-name="tech_sum_86400" id="SS_20" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="tech_sum_86400"/>
# <label class="pointer" for="SS_20" title="Daily">
# Daily </label>
# </li>
# <li class="displayNone">
# <input data-column-name="tech_sum_week" id="SS_21" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="tech_sum_week"/>
# <label class="pointer" for="SS_21" title="Weekly">
# Weekly </label>
# </li>
# <li class="displayNone">
# <input data-column-name="tech_sum_month" id="SS_22" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="tech_sum_month"/>
# <label class="pointer" for="SS_22" title="Monthly">
# Monthly </label>
# </li>
# <li class="displayNone">
# <input data-column-name="daily" id="SS_23" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="daily"/>
# <label class="pointer" for="SS_23" title="Daily">
# Daily </label>
# </li>
# <li class="displayNone">
# <input data-column-name="week" id="SS_24" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="week"/>
# <label class="pointer" for="SS_24" title="1 Week">
# 1 Week </label>
# </li>
# <li class="displayNone">
# <input data-column-name="month" id="SS_25" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="month"/>
# <label class="pointer" for="SS_25" title="1 Month">
# 1 Month </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ytd" id="SS_26" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ytd"/>
# <label class="pointer" for="SS_26" title="YTD">
# YTD </label>
# </li>
# <li class="displayNone">
# <input data-column-name="year" id="SS_27" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="year"/>
# <label class="pointer" for="SS_27" title="1 Year">
# 1 Year </label>
# </li>
# <li class="displayNone">
# <input data-column-name="3year" id="SS_28" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="3year"/>
# <label class="pointer" for="SS_28" title="3 Years">
# 3 Years </label>
# </li>
# <li class="displayNone">
# <input data-column-name="eq_one_year_return" id="SS_29" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="eq_one_year_return"/>
# <label class="pointer" for="SS_29" title="1-Year Change">
# 1-Year Change </label>
# </li>
# <li class="displayNone">
# <input data-column-name="yield_us" id="SS_30" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="yield_us"/>
# <label class="pointer" for="SS_30" title="Dividend Yield (%)">
# Dividend Yield (%) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="peexclxor_us" id="SS_31" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="peexclxor_us"/>
# <label class="pointer" for="SS_31" title="P/E Ratio (TTM)">
# P/E Ratio (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmpr2rev_us" id="SS_32" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmpr2rev_us"/>
# <label class="pointer" for="SS_32" title="Price to Sales (TTM)">
# Price to Sales (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="aprfcfps_us" id="SS_33" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="aprfcfps_us"/>
# <label class="pointer" for="SS_33" title="Price to Cash Flow (MRQ)">
# Price to Cash Flow (MRQ) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmprfcfps_us" id="SS_34" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmprfcfps_us"/>
# <label class="pointer" for="SS_34" title="Price to Free Cash Flow (TTM)">
# Price to Free Cash Flow (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="price2bk_us" id="SS_35" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="price2bk_us"/>
# <label class="pointer" for="SS_35" title="Price to Book (MRQ)">
# Price to Book (MRQ) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="pr2tanbk_us" id="SS_36" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="pr2tanbk_us"/>
# <label class="pointer" for="SS_36" title="Price to Tangible Book (MRQ)">
# Price to Tangible Book (MRQ) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="epschngyr_us" id="SS_37" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="epschngyr_us"/>
# <label class="pointer" for="SS_37" title="EPS(MRQ) vs Qtr. 1 Yr. Ago">
# EPS(MRQ) vs Qtr. 1 Yr. Ago </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmepschg_us" id="SS_38" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmepschg_us"/>
# <label class="pointer" for="SS_38" title="EPS(TTM) vs TTM 1 Yr. Ago">
# EPS(TTM) vs TTM 1 Yr. Ago </label>
# </li>
# <li class="displayNone">
# <input data-column-name="epstrendgr_us" id="SS_39" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="epstrendgr_us"/>
# <label class="pointer" for="SS_39" title="5 Year EPS Growth">
# 5 Year EPS Growth </label>
# </li>
# <li class="displayNone">
# <input data-column-name="revchngyr_us" id="SS_40" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="revchngyr_us"/>
# <label class="pointer" for="SS_40" title="Sales (MRQ) vs Qtr. 1 Yr. Ago">
# Sales (MRQ) vs Qtr. 1 Yr. Ago </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmrevchg_us" id="SS_41" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmrevchg_us"/>
# <label class="pointer" for="SS_41" title="Sales (TTM) vs TTM 1 Yr. Ago (TTM)">
# Sales (TTM) vs TTM 1 Yr. Ago (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="revtrendgr_us" id="SS_42" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="revtrendgr_us"/>
# <label class="pointer" for="SS_42" title="5 Year Sales Growth">
# 5 Year Sales Growth </label>
# </li>
# <li class="displayNone">
# <input data-column-name="csptrendgr_us" id="SS_43" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="csptrendgr_us"/>
# <label class="pointer" for="SS_43" title="5 Year Capital Spending Growth">
# 5 Year Capital Spending Growth </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmastturn_us" id="SS_44" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmastturn_us"/>
# <label class="pointer" for="SS_44" title="Asset Turnover (TTM)">
# Asset Turnover (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttminvturn_us" id="SS_45" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttminvturn_us"/>
# <label class="pointer" for="SS_45" title="Inventory Turnover (TTM)">
# Inventory Turnover (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmrevpere_us" id="SS_46" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmrevpere_us"/>
# <label class="pointer" for="SS_46" title="Revenue/Employee (TTM)">
# Revenue/Employee (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmniperem_us" id="SS_47" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmniperem_us"/>
# <label class="pointer" for="SS_47" title="Net Income/Employee (TTM)">
# Net Income/Employee (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmrecturn_us" id="SS_48" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmrecturn_us"/>
# <label class="pointer" for="SS_48" title="Receivable Turnover (TTM)">
# Receivable Turnover (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="a52_week_high" id="SS_49" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="a52_week_high"/>
# <label class="pointer" for="SS_49" title="52 wk Range - High">
# 52 wk Range - High </label>
# </li>
# <li class="displayNone">
# <input data-column-name="a52_week_low" id="SS_50" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="a52_week_low"/>
# <label class="pointer" for="SS_50" title="52 wk Range - Low">
# 52 wk Range - Low </label>
# </li>
# <li class="displayNone">
# <input data-column-name="a52_week_high_diff" id="SS_51" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="a52_week_high_diff"/>
# <label class="pointer" for="SS_51" title="% Change from 52 wk High">
# % Change from 52 wk High </label>
# </li>
# <li class="displayNone">
# <input data-column-name="a52_week_low_diff" id="SS_52" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="a52_week_low_diff"/>
# <label class="pointer" for="SS_52" title="% Change from 52 wk Low">
# % Change from 52 wk Low </label>
# </li>
# <li class="displayNone">
# <input data-column-name="month_change" id="SS_53" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="month_change"/>
# <label class="pointer" for="SS_53" title="Previous Month % Change">
# Previous Month % Change </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmgrosmgn_us" id="SS_54" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmgrosmgn_us"/>
# <label class="pointer" for="SS_54" title="Gross margin (TTM)">
# Gross margin (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="grosmgn5yr_us" id="SS_55" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="grosmgn5yr_us"/>
# <label class="pointer" for="SS_55" title="Gross Margin (5YA)">
# Gross Margin (5YA) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmopmgn_us" id="SS_56" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmopmgn_us"/>
# <label class="pointer" for="SS_56" title="Operating margin (TTM)">
# Operating margin (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="opmgn5yr_us" id="SS_57" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="opmgn5yr_us"/>
# <label class="pointer" for="SS_57" title="Operating margin (5YA)">
# Operating margin (5YA) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmptmgn_us" id="SS_58" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmptmgn_us"/>
# <label class="pointer" for="SS_58" title="Pretax margin (TTM)">
# Pretax margin (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ptmgn5yr_us" id="SS_59" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ptmgn5yr_us"/>
# <label class="pointer" for="SS_59" title="Pretax margin (5YA)">
# Pretax margin (5YA) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmnpmgn_us" id="SS_60" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmnpmgn_us"/>
# <label class="pointer" for="SS_60" title="Net Profit margin (TTM)">
# Net Profit margin (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="margin5yr_us" id="SS_61" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="margin5yr_us"/>
# <label class="pointer" for="SS_61" title="Net Profit margin (5YA)">
# Net Profit margin (5YA) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="qquickrati_us" id="SS_62" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="qquickrati_us"/>
# <label class="pointer" for="SS_62" title="Quick Ratio (MRQ)">
# Quick Ratio (MRQ) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="qcurratio_us" id="SS_63" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="qcurratio_us"/>
# <label class="pointer" for="SS_63" title="Current Ratio (MRQ)">
# Current Ratio (MRQ) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="qltd2eq_us" id="SS_64" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="qltd2eq_us"/>
# <label class="pointer" for="SS_64" title="LT Debt to Equity (MRQ)">
# LT Debt to Equity (MRQ) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="qtotd2eq_us" id="SS_65" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="qtotd2eq_us"/>
# <label class="pointer" for="SS_65" title="Total Debt to Equity">
# Total Debt to Equity </label>
# </li>
# <li class="displayNone">
# <input data-column-name="yld5yavg_us" id="SS_66" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="yld5yavg_us"/>
# <label class="pointer" for="SS_66" title="Dividend Yield 5 Year Avg. (5YA)">
# Dividend Yield 5 Year Avg. (5YA) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="divgrpct_us" id="SS_67" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="divgrpct_us"/>
# <label class="pointer" for="SS_67" title="Dividend Growth Rate (ANN)">
# Dividend Growth Rate (ANN) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ttmpayrat_us" id="SS_68" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ttmpayrat_us"/>
# <label class="pointer" for="SS_68" title="Payout Ratio (TTM)">
# Payout Ratio (TTM) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ADX" id="SS_69" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ADX"/>
# <label class="pointer" for="SS_69" title="ADX (14 / 1D)">
# ADX (14 / 1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ATR" id="SS_70" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ATR"/>
# <label class="pointer" for="SS_70" title="ATR (14 / 1D)">
# ATR (14 / 1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="BullBear" id="SS_71" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="BullBear"/>
# <label class="pointer" for="SS_71" title="Bull/Bear Power (13 / 1D)">
# Bull/Bear Power (13 / 1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="CCI" id="SS_72" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="CCI"/>
# <label class="pointer" for="SS_72" title="CCI (14 / 1D)">
# CCI (14 / 1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="HL" id="SS_73" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="HL"/>
# <label class="pointer" for="SS_73" title="Highs/Lows (14 / 1D)">
# Highs/Lows (14 / 1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="ROC" id="SS_74" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="ROC"/>
# <label class="pointer" for="SS_74" title="ROC (1D)">
# ROC (1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="RSI" id="SS_75" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="RSI"/>
# <label class="pointer" for="SS_75" title="RSI (14 / 1D)">
# RSI (14 / 1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="STOCH" id="SS_76" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="STOCH"/>
# <label class="pointer" for="SS_76" title="STOCH (14 / 1D)">
# STOCH (14 / 1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="STOCHRSI" id="SS_77" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="STOCHRSI"/>
# <label class="pointer" for="SS_77" title="STOCHRSI (14 / 1D)">
# STOCHRSI (14 / 1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="UO" id="SS_78" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="UO"/>
# <label class="pointer" for="SS_78" title="Ultimate Oscillator (14 /1D)">
# Ultimate Oscillator (14 /1D) </label>
# </li>
# <li class="displayNone">
# <input data-column-name="WilliamsR" id="SS_79" onclick="columnsSettings_stock_screener.onCheckboxClick(this);" type="checkbox" value="WilliamsR"/>
# <label class="pointer" for="SS_79" title="Williams %R (1D)">
# Williams %R (1D) </label>
# </li>
# </ul>
# </div>
# <div>
# <div style="position: relative;vertical-align:middle;float:right;display:block;padding:3px 15px 0;white-space: nowrap;overflow: hidden;text-overflow: ellipsis;width: 130px;text-align:right;">
# <a href="/pro/screener?entry=screener_column_settings" style="font-family: Arial, Helvetica, sans-serif;font-style: normal;font-weight: bold;font-size: 11px;line-height: 31px;color: #164B93;text-decoration:none;" target="_blank">
# <img alt="InvestingPro" height="15" src="https://i-invdn-com.investing.com/InvestingProShield.svg" style="vertical-align:middle;margin-right:4px;top:-2px;position:relative;"/>Advanced Metrics </a>
# </div>
# <div class="colsSelectMessage" id="resultsContainerColsSelectMessage">
# Currently selected: <span>6</span> (max 8 ) </div>
# </div>
# </div>
# <div class="footer">
# <a class="newBtn float_lang_base_2 noIcon Orange2" href="javascript:void(0)" id="selectColumnsButton_stock_screener" onclick='columnsSettings_stock_screener.onApplyClick(window.stockScreenerColumnsApply, "");'>Apply</a> </div>
# </div>
# </form>
# <script>
# 	$('#colSelectPopup_stock_screener').click(function(e) {
# 		e.stopPropagation();
# 	});
# </script>
# </th>
# </tr>
# </thead>
# <tbody><tr>
# <td class="flag"><span class="ceFlags USA"></span></td>
# <td class="symbol left bold elp" data-column-name="name_trans"><a href="/equities/microsoft-corp" target="_blank" title="Microsoft Corporation">Microsoft</a></td>
# <td class="left" data-column-name="viewData.symbol">MSFT</td>
# <td class="left displayNone" data-column-name="exchange_trans">NASDAQ</td><td class="left displayNone" data-column-name="sector_trans">Technology</td><td class="left displayNone" data-column-name="industry_trans">Software &amp; IT Services</td><td data-column-name="last">423.85</td><td data-column-name="pair_change_percent">-0.16%</td><td data-column-name="eq_market_cap">3.15T</td><td data-column-name="turnover_volume">13.04M</td><td class="displayNone" data-column-name="eq_pe_ratio">36.60</td><td class="displayNone" data-column-name="MACD">1.31</td><td class="displayNone" data-column-name="eq_revenue">236.58B</td><td class="displayNone" data-column-name="avg_volume">19.53M</td><td class="displayNone" data-column-name="eq_eps">11.60</td><td class="displayNone" data-column-name="eq_beta">0.89</td><td class="displayNone" data-column-name="eq_dividend">3.00</td><td class="displayNone" data-column-name="eq_yield">-</td><td class="left displayNone" data-column-name="tech_sum_900">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_3600">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_86400">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_week">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_month">Strong Buy</td><td class="displayNone" data-column-name="daily">-0.16</td><td class="displayNone" data-column-name="week">2.10</td><td class="displayNone" data-column-name="month">2.80</td><td class="displayNone" data-column-name="ytd">12.71</td><td class="displayNone" data-column-name="year">29.70</td><td class="displayNone" data-column-name="3year">67.14</td><td class="displayNone" data-column-name="eq_one_year_return">30.31</td><td class="displayNone" data-column-name="yield_us">0.71%</td><td class="displayNone" data-column-name="peexclxor_us">36.75</td><td class="displayNone" data-column-name="ttmpr2rev_us">13.39</td><td class="displayNone" data-column-name="aprfcfps_us">30.35</td><td class="displayNone" data-column-name="ttmprfcfps_us">44.87</td><td class="displayNone" data-column-name="price2bk_us">12.51</td><td class="displayNone" data-column-name="pr2tanbk_us">30.00</td><td class="displayNone" data-column-name="epschngyr_us">20.05</td><td class="displayNone" data-column-name="ttmepschg_us">25.26</td><td class="displayNone" data-column-name="epstrendgr_us">35.19</td><td class="displayNone" data-column-name="revchngyr_us">17.03</td><td class="displayNone" data-column-name="ttmrevchg_us">13.97</td><td class="displayNone" data-column-name="revtrendgr_us">13.94</td><td class="displayNone" data-column-name="csptrendgr_us">19.30</td><td class="displayNone" data-column-name="ttmastturn_us">0.55</td><td class="displayNone" data-column-name="ttminvturn_us">34.07</td><td class="displayNone" data-column-name="ttmrevpere_us">1.07</td><td class="displayNone" data-column-name="ttmniperem_us">389.96</td><td class="displayNone" data-column-name="ttmrecturn_us">5.70</td><td class="displayNone" data-column-name="a52_week_high">433.6</td><td class="displayNone" data-column-name="a52_week_low">309.45</td><td class="displayNone" data-column-name="a52_week_high_diff">-2.25</td><td class="displayNone" data-column-name="a52_week_low_diff">36.97</td><td class="displayNone" data-column-name="month_change">6.63%</td><td class="displayNone" data-column-name="ttmgrosmgn_us">69.89</td><td class="displayNone" data-column-name="grosmgn5yr_us">68.40</td><td class="displayNone" data-column-name="ttmopmgn_us">44.70</td><td class="displayNone" data-column-name="opmgn5yr_us">40.40</td><td class="displayNone" data-column-name="ttmptmgn_us">44.49</td><td class="displayNone" data-column-name="ptmgn5yr_us">40.60</td><td class="displayNone" data-column-name="ttmnpmgn_us">36.43</td><td class="displayNone" data-column-name="margin5yr_us">34.58</td><td class="displayNone" data-column-name="qquickrati_us">1.05</td><td class="displayNone" data-column-name="qcurratio_us">1.24</td><td class=" ...
# </tr><tr>
# <td class="flag"><span class="ceFlags USA"></span></td>
# <td class="symbol left bold elp" data-column-name="name_trans"><a href="/equities/apple-computer-inc" target="_blank" title="Apple Inc">Apple</a></td>
# <td class="left" data-column-name="viewData.symbol">AAPL</td>
# <td class="left displayNone" data-column-name="exchange_trans">NASDAQ</td><td class="left displayNone" data-column-name="sector_trans">Technology</td><td class="left displayNone" data-column-name="industry_trans">Computers, Phones &amp; Household Electronics</td><td data-column-name="last">196.89</td><td data-column-name="pair_change_percent">1.24%</td><td data-column-name="eq_market_cap">3.02T</td><td data-column-name="turnover_volume">46.32M</td><td class="displayNone" data-column-name="eq_pe_ratio">30.40</td><td class="displayNone" data-column-name="MACD">4.55</td><td class="displayNone" data-column-name="eq_revenue">381.62B</td><td class="displayNone" data-column-name="avg_volume">60.36M</td><td class="displayNone" data-column-name="eq_eps">6.45</td><td class="displayNone" data-column-name="eq_beta">1.28</td><td class="displayNone" data-column-name="eq_dividend">1.00</td><td class="displayNone" data-column-name="eq_yield">-</td><td class="left displayNone" data-column-name="tech_sum_900">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_3600">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_86400">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_week">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_month">Strong Buy</td><td class="displayNone" data-column-name="daily">1.24</td><td class="displayNone" data-column-name="week">2.41</td><td class="displayNone" data-column-name="month">6.67</td><td class="displayNone" data-column-name="ytd">2.26</td><td class="displayNone" data-column-name="year">8.80</td><td class="displayNone" data-column-name="3year">54.87</td><td class="displayNone" data-column-name="eq_one_year_return">9.04</td><td class="displayNone" data-column-name="yield_us">0.51%</td><td class="displayNone" data-column-name="peexclxor_us">29.92</td><td class="displayNone" data-column-name="ttmpr2rev_us">7.87</td><td class="displayNone" data-column-name="aprfcfps_us">23.67</td><td class="displayNone" data-column-name="ttmprfcfps_us">29.48</td><td class="displayNone" data-column-name="price2bk_us">40.49</td><td class="displayNone" data-column-name="pr2tanbk_us">40.19</td><td class="displayNone" data-column-name="epschngyr_us">0.25</td><td class="displayNone" data-column-name="ttmepschg_us">9.27</td><td class="displayNone" data-column-name="epstrendgr_us">15.45</td><td class="displayNone" data-column-name="revchngyr_us">-4.31</td><td class="displayNone" data-column-name="ttmrevchg_us">-0.90</td><td class="displayNone" data-column-name="revtrendgr_us">7.61</td><td class="displayNone" data-column-name="csptrendgr_us">-3.82</td><td class="displayNone" data-column-name="ttmastturn_us">1.14</td><td class="displayNone" data-column-name="ttminvturn_us">30.28</td><td class="displayNone" data-column-name="ttmrevpere_us">2.37</td><td class="displayNone" data-column-name="ttmniperem_us">623.53</td><td class="displayNone" data-column-name="ttmrecturn_us">16.12</td><td class="displayNone" data-column-name="a52_week_high">199.62</td><td class="displayNone" data-column-name="a52_week_low">164.07</td><td class="displayNone" data-column-name="a52_week_high_diff">-1.37</td><td class="displayNone" data-column-name="a52_week_low_diff">20.00</td><td class="displayNone" data-column-name="month_change">12.87%</td><td class="displayNone" data-column-name="ttmgrosmgn_us">45.59</td><td class="displayNone" data-column-name="grosmgn5yr_us">41.35</td><td class="displayNone" data-column-name="ttmopmgn_us">30.98</td><td class="displayNone" data-column-name="opmgn5yr_us">28.02</td><td class="displayNone" data-column-name="ttmptmgn_us">30.95</td><td class="displayNone" data-column-name="ptmgn5yr_us">28.16</td><td class="displayNone" data-column-name="ttmnpmgn_us">26.31</td><td class="displayNone" data-column-name="margin5yr_us">23.97</td><td class="displayNone" data-column-name="qquickrati_us">0.72</td><td class="displayNone" data-column-name="qcurratio_us">1.04</td> ...
# </tr><tr>
# <td class="flag"><span class="ceFlags USA"></span></td>
# <td class="symbol left bold elp" data-column-name="name_trans"><a href="/equities/nvidia-corp" target="_blank" title="NVIDIA Corporation">NVIDIA</a></td>
# <td class="left" data-column-name="viewData.symbol">NVDA</td>
# <td class="left displayNone" data-column-name="exchange_trans">NASDAQ</td><td class="left displayNone" data-column-name="sector_trans">Technology</td><td class="left displayNone" data-column-name="industry_trans">Semiconductors &amp; Semiconductor Equipment</td><td data-column-name="last">1208.61</td><td data-column-name="pair_change_percent">-0.11%</td><td data-column-name="eq_market_cap">2.97T</td><td data-column-name="turnover_volume">38.68M</td><td class="displayNone" data-column-name="eq_pe_ratio">69.73</td><td class="displayNone" data-column-name="MACD">81.40</td><td class="displayNone" data-column-name="eq_revenue">79.77B</td><td class="displayNone" data-column-name="avg_volume">49.12M</td><td class="displayNone" data-column-name="eq_eps">17.27</td><td class="displayNone" data-column-name="eq_beta">1.69</td><td class="displayNone" data-column-name="eq_dividend">0.04</td><td class="displayNone" data-column-name="eq_yield">-</td><td class="left displayNone" data-column-name="tech_sum_900">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_3600">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_86400">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_week">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_month">Strong Buy</td><td class="displayNone" data-column-name="daily">-0.11</td><td class="displayNone" data-column-name="week">10.24</td><td class="displayNone" data-column-name="month">36.19</td><td class="displayNone" data-column-name="ytd">144.06</td><td class="displayNone" data-column-name="year">211.74</td><td class="displayNone" data-column-name="3year">596.27</td><td class="displayNone" data-column-name="eq_one_year_return">213.84</td><td class="displayNone" data-column-name="yield_us">-</td><td class="displayNone" data-column-name="peexclxor_us">69.63</td><td class="displayNone" data-column-name="ttmpr2rev_us">37.18</td><td class="displayNone" data-column-name="aprfcfps_us">80.67</td><td class="displayNone" data-column-name="ttmprfcfps_us">75.41</td><td class="displayNone" data-column-name="price2bk_us">60.36</td><td class="displayNone" data-column-name="pr2tanbk_us">68.06</td><td class="displayNone" data-column-name="epschngyr_us">630.76</td><td class="displayNone" data-column-name="ttmepschg_us">792.72</td><td class="displayNone" data-column-name="epstrendgr_us">47.91</td><td class="displayNone" data-column-name="revchngyr_us">262.12</td><td class="displayNone" data-column-name="ttmrevchg_us">208.27</td><td class="displayNone" data-column-name="revtrendgr_us">39.06</td><td class="displayNone" data-column-name="csptrendgr_us">12.24</td><td class="displayNone" data-column-name="ttmastturn_us">1.31</td><td class="displayNone" data-column-name="ttminvturn_us">3.76</td><td class="displayNone" data-column-name="ttmrevpere_us">2.70</td><td class="displayNone" data-column-name="ttmniperem_us">1.44</td><td class="displayNone" data-column-name="ttmrecturn_us">9.32</td><td class="displayNone" data-column-name="a52_week_high">1255.87</td><td class="displayNone" data-column-name="a52_week_low">386.18</td><td class="displayNone" data-column-name="a52_week_high_diff">-3.76</td><td class="displayNone" data-column-name="a52_week_low_diff">212.97</td><td class="displayNone" data-column-name="month_change">26.89%</td><td class="displayNone" data-column-name="ttmgrosmgn_us">75.29</td><td class="displayNone" data-column-name="grosmgn5yr_us">63.51</td><td class="displayNone" data-column-name="ttmopmgn_us">59.85</td><td class="displayNone" data-column-name="opmgn5yr_us">32.32</td><td class="displayNone" data-column-name="ttmptmgn_us">61.28</td><td class="displayNone" data-column-name="ptmgn5yr_us">31.39</td><td class="displayNone" data-column-name="ttmnpmgn_us">53.40</td><td class="displayNone" data-column-name="margin5yr_us">30.11</td><td class="displayNone" data-column-name="qquickrati_us">2.88</td><td class="displayNone" data-column-name="qcurratio ...
# </tr><tr>
# <td class="flag"><span class="ceFlags USA"></span></td>
# <td class="symbol left bold elp" data-column-name="name_trans"><a href="/equities/google-inc" target="_blank" title="Alphabet Inc Class A">Alphabet A</a></td>
# <td class="left" data-column-name="viewData.symbol">GOOGL</td>
# <td class="left displayNone" data-column-name="exchange_trans">NASDAQ</td><td class="left displayNone" data-column-name="sector_trans">Technology</td><td class="left displayNone" data-column-name="industry_trans">Software &amp; IT Services</td><td data-column-name="last">174.45</td><td data-column-name="pair_change_percent">-1.29%</td><td data-column-name="eq_market_cap">2.16T</td><td data-column-name="turnover_volume">13.96M</td><td class="displayNone" data-column-name="eq_pe_ratio">27.04</td><td class="displayNone" data-column-name="MACD">2.72</td><td class="displayNone" data-column-name="eq_revenue">318.15B</td><td class="displayNone" data-column-name="avg_volume">27.86M</td><td class="displayNone" data-column-name="eq_eps">6.57</td><td class="displayNone" data-column-name="eq_beta">1.01</td><td class="displayNone" data-column-name="eq_dividend">0.80</td><td class="displayNone" data-column-name="eq_yield">-</td><td class="left displayNone" data-column-name="tech_sum_900">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_3600">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_86400">Buy</td><td class="left displayNone" data-column-name="tech_sum_week">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_month">Strong Buy</td><td class="displayNone" data-column-name="daily">-1.29</td><td class="displayNone" data-column-name="week">1.13</td><td class="displayNone" data-column-name="month">2.64</td><td class="displayNone" data-column-name="ytd">24.88</td><td class="displayNone" data-column-name="year">42.72</td><td class="displayNone" data-column-name="3year">44.90</td><td class="displayNone" data-column-name="eq_one_year_return">42.83</td><td class="displayNone" data-column-name="yield_us">0.45%</td><td class="displayNone" data-column-name="peexclxor_us">26.26</td><td class="displayNone" data-column-name="ttmpr2rev_us">6.80</td><td class="displayNone" data-column-name="aprfcfps_us">16.49</td><td class="displayNone" data-column-name="ttmprfcfps_us">31.32</td><td class="displayNone" data-column-name="price2bk_us">7.39</td><td class="displayNone" data-column-name="pr2tanbk_us">8.32</td><td class="displayNone" data-column-name="epschngyr_us">61.85</td><td class="displayNone" data-column-name="ttmepschg_us">45.36</td><td class="displayNone" data-column-name="epstrendgr_us">21.46</td><td class="displayNone" data-column-name="revchngyr_us">15.41</td><td class="displayNone" data-column-name="ttmrevchg_us">11.78</td><td class="displayNone" data-column-name="revtrendgr_us">17.57</td><td class="displayNone" data-column-name="csptrendgr_us">5.11</td><td class="displayNone" data-column-name="ttmastturn_us">0.82</td><td class="displayNone" data-column-name="ttminvturn_us">116.91</td><td class="displayNone" data-column-name="ttmrevpere_us">1.76</td><td class="displayNone" data-column-name="ttmniperem_us">455.55</td><td class="displayNone" data-column-name="ttmrecturn_us">6.96</td><td class="displayNone" data-column-name="a52_week_high">178.77</td><td class="displayNone" data-column-name="a52_week_low">115.35</td><td class="displayNone" data-column-name="a52_week_high_diff">-2.42</td><td class="displayNone" data-column-name="a52_week_low_diff">51.24</td><td class="displayNone" data-column-name="month_change">5.97%</td><td class="displayNone" data-column-name="ttmgrosmgn_us">57.47</td><td class="displayNone" data-column-name="grosmgn5yr_us">55.66</td><td class="displayNone" data-column-name="ttmopmgn_us">30.49</td><td class="displayNone" data-column-name="opmgn5yr_us">25.93</td><td class="displayNone" data-column-name="ttmptmgn_us">30.12</td><td class="displayNone" data-column-name="ptmgn5yr_us">27.94</td><td class="displayNone" data-column-name="ttmnpmgn_us">25.90</td><td class="displayNone" data-column-name="margin5yr_us">23.72</td><td class="displayNone" data-column-name="qquickrati_us">1.98</td><td class="displayNone" data-column-name="qcurratio_us">2.15</td><td class="displayNo ...
# </tr><tr>
# <td class="flag"><span class="ceFlags USA"></span></td>
# <td class="symbol left bold elp" data-column-name="name_trans"><a href="/equities/google-inc-c" target="_blank" title="Alphabet Inc Class C">Alphabet C</a></td>
# <td class="left" data-column-name="viewData.symbol">GOOG</td>
# ...
# </tr><tr>
# <td class="flag"><span class="ceFlags USA"></span></td>
# <td class="symbol left bold elp" data-column-name="name_trans"><a href="/equities/toyota" target="_blank" title="Toyota Motor Corporation ADR">Toyota Motor ADR</a></td>
# <td class="left" data-column-name="viewData.symbol">TM</td>
# <td class="left displayNone" data-column-name="exchange_trans">NYSE</td><td class="left displayNone" data-column-name="sector_trans">Consumer Cyclicals</td><td class="left displayNone" data-column-name="industry_trans">Automobiles &amp; Auto Parts</td><td data-column-name="last">206.36</td><td data-column-name="pair_change_percent">-1.75%</td><td data-column-name="eq_market_cap">276.64B</td><td data-column-name="turnover_volume">536.99K</td><td class="displayNone" data-column-name="eq_pe_ratio">8.77</td><td class="displayNone" data-column-name="MACD">-5.58</td><td class="displayNone" data-column-name="eq_revenue">45.10T</td><td class="displayNone" data-column-name="avg_volume">273.16K</td><td class="displayNone" data-column-name="eq_eps">365.94</td><td class="displayNone" data-column-name="eq_beta">0.51</td><td class="displayNone" data-column-name="eq_dividend">4.33</td><td class="displayNone" data-column-name="eq_yield">-</td><td class="left displayNone" data-column-name="tech_sum_900">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_3600">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_86400">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_week">Sell</td><td class="left displayNone" data-column-name="tech_sum_month">Strong Buy</td><td class="displayNone" data-column-name="daily">-1.75</td><td class="displayNone" data-column-name="week">-5.13</td><td class="displayNone" data-column-name="month">-9.19</td><td class="displayNone" data-column-name="ytd">12.53</td><td class="displayNone" data-column-name="year">38.83</td><td class="displayNone" data-column-name="3year">14.30</td><td class="displayNone" data-column-name="eq_one_year_return">40.51</td><td class="displayNone" data-column-name="yield_us">2.06%</td><td class="displayNone" data-column-name="peexclxor_us">8.77</td><td class="displayNone" data-column-name="ttmpr2rev_us">0.96</td><td class="displayNone" data-column-name="aprfcfps_us">10.31</td><td class="displayNone" data-column-name="ttmprfcfps_us">-85.39</td><td class="displayNone" data-column-name="price2bk_us">1.27</td><td class="displayNone" data-column-name="pr2tanbk_us">1.34</td><td class="displayNone" data-column-name="epschngyr_us">82.01</td><td class="displayNone" data-column-name="ttmepschg_us">103.90</td><td class="displayNone" data-column-name="epstrendgr_us">22.98</td><td class="displayNone" data-column-name="revchngyr_us">14.27</td><td class="displayNone" data-column-name="ttmrevchg_us">21.37</td><td class="displayNone" data-column-name="revtrendgr_us">8.33</td><td class="displayNone" data-column-name="csptrendgr_us">4.74</td><td class="displayNone" data-column-name="ttmastturn_us">0.55</td><td class="displayNone" data-column-name="ttminvturn_us">7.58</td><td class="displayNone" data-column-name="ttmrevpere_us">118.42</td><td class="displayNone" data-column-name="ttmniperem_us">13.32</td><td class="displayNone" data-column-name="ttmrecturn_us">10.66</td><td class="displayNone" data-column-name="a52_week_high">255.23</td><td class="displayNone" data-column-name="a52_week_low">148.74</td><td class="displayNone" data-column-name="a52_week_high_diff">-19.15</td><td class="displayNone" data-column-name="a52_week_low_diff">38.74</td><td class="displayNone" data-column-name="month_change">-4.31%</td><td class="displayNone" data-column-name="ttmgrosmgn_us">20.77</td><td class="displayNone" data-column-name="grosmgn5yr_us">18.25</td><td class="displayNone" data-column-name="ttmopmgn_us">11.87</td><td class="displayNone" data-column-name="opmgn5yr_us">8.65</td><td class="displayNone" data-column-name="ttmptmgn_us">15.45</td><td class="displayNone" data-column-name="ptmgn5yr_us">11.02</td><td class="displayNone" data-column-name="ttmnpmgn_us">10.97</td><td class="displayNone" data-column-name="margin5yr_us">8.13</td><td class="displayNone" data-column-name="qquickrati_us">0.53</td><td class="displayNone" data-column-name="qcurratio_us">1.19</td><td ...
# </tr><tr>
# <td class="flag"><span class="ceFlags USA"></span></td>
# <td class="symbol left bold elp" data-column-name="name_trans"><a href="/equities/toyota-motor-corporation?cid=53018" target="_blank" title="Toyota Motor Corp">Toyota Motor</a></td>
# <td class="left" data-column-name="viewData.symbol">TOYOF</td>
# <td class="left displayNone" data-column-name="exchange_trans">OTC Markets</td><td class="left displayNone" data-column-name="sector_trans">Consumer Cyclicals</td><td class="left displayNone" data-column-name="industry_trans">Automobiles &amp; Auto Parts</td><td data-column-name="last">20.75</td><td data-column-name="pair_change_percent">-1.43%</td><td data-column-name="eq_market_cap">276.64B</td><td data-column-name="turnover_volume">6.14K</td><td class="displayNone" data-column-name="eq_pe_ratio">8.77</td><td class="displayNone" data-column-name="MACD">-0.53</td><td class="displayNone" data-column-name="eq_revenue">45.10T</td><td class="displayNone" data-column-name="avg_volume">99.42K</td><td class="displayNone" data-column-name="eq_eps">365.94</td><td class="displayNone" data-column-name="eq_beta">0.51</td><td class="displayNone" data-column-name="eq_dividend">-</td><td class="displayNone" data-column-name="eq_yield">-</td><td class="left displayNone" data-column-name="tech_sum_900">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_3600">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_86400">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_week">Sell</td><td class="left displayNone" data-column-name="tech_sum_month">Strong Buy</td><td class="displayNone" data-column-name="daily">-1.43</td><td class="displayNone" data-column-name="week">-4.25</td><td class="displayNone" data-column-name="month">-8.95</td><td class="displayNone" data-column-name="ytd">13.15</td><td class="displayNone" data-column-name="year">39.73</td><td class="displayNone" data-column-name="3year">14.31</td><td class="displayNone" data-column-name="eq_one_year_return">40.63</td><td class="displayNone" data-column-name="yield_us">-</td><td class="displayNone" data-column-name="peexclxor_us">8.91</td><td class="displayNone" data-column-name="ttmpr2rev_us">0.74</td><td class="displayNone" data-column-name="aprfcfps_us">10.48</td><td class="displayNone" data-column-name="ttmprfcfps_us">-86.82</td><td class="displayNone" data-column-name="price2bk_us">1.02</td><td class="displayNone" data-column-name="pr2tanbk_us">1.14</td><td class="displayNone" data-column-name="epschngyr_us">-80.36</td><td class="displayNone" data-column-name="ttmepschg_us">-19.44</td><td class="displayNone" data-column-name="epstrendgr_us">22.35</td><td class="displayNone" data-column-name="revchngyr_us">2.57</td><td class="displayNone" data-column-name="ttmrevchg_us">2.80</td><td class="displayNone" data-column-name="revtrendgr_us">5.89</td><td class="displayNone" data-column-name="csptrendgr_us">12.76</td><td class="displayNone" data-column-name="ttmastturn_us">0.59</td><td class="displayNone" data-column-name="ttminvturn_us">9.58</td><td class="displayNone" data-column-name="ttmrevpere_us">81.43</td><td class="displayNone" data-column-name="ttmniperem_us">4.44</td><td class="displayNone" data-column-name="ttmrecturn_us">3.49</td><td class="displayNone" data-column-name="a52_week_high">26.02</td><td class="displayNone" data-column-name="a52_week_low">14.851</td><td class="displayNone" data-column-name="a52_week_high_diff">-20.25</td><td class="displayNone" data-column-name="a52_week_low_diff">39.72</td><td class="displayNone" data-column-name="month_change">-4.52%</td><td class="displayNone" data-column-name="ttmgrosmgn_us">18.80</td><td class="displayNone" data-column-name="grosmgn5yr_us">19.11</td><td class="displayNone" data-column-name="ttmopmgn_us">7.36</td><td class="displayNone" data-column-name="opmgn5yr_us">8.89</td><td class="displayNone" data-column-name="ttmptmgn_us">7.80</td><td class="displayNone" data-column-name="ptmgn5yr_us">9.49</td><td class="displayNone" data-column-name="ttmnpmgn_us">5.45</td><td class="displayNone" data-column-name="margin5yr_us">6.84</td><td class="displayNone" data-column-name="qquickrati_us">0.86</td><td class="displayNone" data-column-name="qcurratio_us">1.00</td><td class="disp ...
# </tr><tr>
# <td class="flag"><span class="ceFlags USA"></span></td>
# <td class="symbol left bold elp" data-column-name="name_trans"><a href="/equities/netflix,-inc." target="_blank" title="Netflix Inc">Netflix</a></td>
# <td class="left" data-column-name="viewData.symbol">NFLX</td>
# <td class="left displayNone" data-column-name="exchange_trans">NASDAQ</td><td class="left displayNone" data-column-name="sector_trans">Technology</td><td class="left displayNone" data-column-name="industry_trans">Software &amp; IT Services</td><td data-column-name="last">641.63</td><td data-column-name="pair_change_percent">-1.06%</td><td data-column-name="eq_market_cap">276.41B</td><td data-column-name="turnover_volume">1.61M</td><td class="displayNone" data-column-name="eq_pe_ratio">43.71</td><td class="displayNone" data-column-name="MACD">9.65</td><td class="displayNone" data-column-name="eq_revenue">34.93B</td><td class="displayNone" data-column-name="avg_volume">3.41M</td><td class="displayNone" data-column-name="eq_eps">14.68</td><td class="displayNone" data-column-name="eq_beta">1.22</td><td class="displayNone" data-column-name="eq_dividend">-</td><td class="displayNone" data-column-name="eq_yield">-</td><td class="left displayNone" data-column-name="tech_sum_900">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_3600">Strong Sell</td><td class="left displayNone" data-column-name="tech_sum_86400">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_week">Strong Buy</td><td class="left displayNone" data-column-name="tech_sum_month">Strong Buy</td><td class="displayNone" data-column-name="daily">-1.06</td><td class="displayNone" data-column-name="week">0.00</td><td class="displayNone" data-column-name="month">4.83</td><td class="displayNone" data-column-name="ytd">31.78</td><td class="displayNone" data-column-name="year">52.76</td><td class="displayNone" data-column-name="3year">32.07</td><td class="displayNone" data-column-name="eq_one_year_return">56.74</td><td class="displayNone" data-column-name="yield_us">-</td><td class="displayNone" data-column-name="peexclxor_us">43.05</td><td class="displayNone" data-column-name="ttmpr2rev_us">7.93</td><td class="displayNone" data-column-name="aprfcfps_us">35.19</td><td class="displayNone" data-column-name="ttmprfcfps_us">39.88</td><td class="displayNone" data-column-name="price2bk_us">12.97</td><td class="displayNone" data-column-name="pr2tanbk_us">31.70</td><td class="displayNone" data-column-name="epschngyr_us">84.14</td><td class="displayNone" data-column-name="ttmepschg_us">55.57</td><td class="displayNone" data-column-name="epstrendgr_us">34.50</td><td class="displayNone" data-column-name="revchngyr_us">14.81</td><td class="displayNone" data-column-name="ttmrevchg_us">9.47</td><td class="displayNone" data-column-name="revtrendgr_us">16.38</td><td class="displayNone" data-column-name="csptrendgr_us">14.91</td><td class="displayNone" data-column-name="ttmastturn_us">0.71</td><td class="displayNone" data-column-name="ttminvturn_us">0.00</td><td class="displayNone" data-column-name="ttmrevpere_us">2.69</td><td class="displayNone" data-column-name="ttmniperem_us">495.01</td><td class="displayNone" data-column-name="ttmrecturn_us">29.80</td><td class="displayNone" data-column-name="a52_week_high">664.25</td><td class="displayNone" data-column-name="a52_week_low">344.73</td><td class="displayNone" data-column-name="a52_week_high_diff">-3.41</td><td class="displayNone" data-column-name="a52_week_low_diff">86.13</td><td class="displayNone" data-column-name="month_change">16.52%</td><td class="displayNone" data-column-name="ttmgrosmgn_us">43.06</td><td class="displayNone" data-column-name="grosmgn5yr_us">39.94</td><td class="displayNone" data-column-name="ttmopmgn_us">22.54</td><td class="displayNone" data-column-name="opmgn5yr_us">18.04</td><td class="displayNone" data-column-name="ttmptmgn_us">21.04</td><td class="displayNone" data-column-name="ptmgn5yr_us">15.54</td><td class="displayNone" data-column-name="ttmnpmgn_us">18.42</td><td class="displayNone" data-column-name="margin5yr_us">13.56</td><td class="displayNone" data-column-name="qquickrati_us">0.89</td><td class="displayNone" data-column-name="qcurratio_us">1.07</td><td class="display ...
# </tr></tbody>
# </table>

# %%
# convert into dataframe
# using prettify() method, BeautifulSoup's parsing parser tree
df_table = pd.read_html(html_table[0].prettify())
df_table_result = df_table[0]
df_table_result.head()
# Out:
#    Unnamed: 0        Name Symbol Exchange      Sector  \
# 0         NaN   Microsoft   MSFT   NASDAQ  Technology
# 1         NaN       Apple   AAPL   NASDAQ  Technology
# 2         NaN      NVIDIA   NVDA   NASDAQ  Technology
# 3         NaN  Alphabet A  GOOGL   NASDAQ  Technology
# 4         NaN  Alphabet C   GOOG   NASDAQ  Technology
#
#                                     Industry     Last  Chg. % Market Cap  \
# 0                     Software & IT Services   423.85  -0.16%      3.15T
# 1  Computers, Phones & Household Electronics   196.89   1.24%      3.02T
# 2   Semiconductors & Semiconductor Equipment  1208.61  -0.11%      2.97T
# 3                     Software & IT Services   174.45  -1.29%      2.16T
# 4                     Software & IT Services   175.95  -1.35%      2.16T
#
#      Vol.  ...  Bull/Bear Power (13 / 1D) CCI (14 / 1D) Highs/Lows (14 / 1D)  \
# 0  13.04M  ...                       6.90         18.90                 0.00
# 1  46.32M  ...                       6.18        148.04                 3.34
# 2  38.68M  ...                     157.09        100.17                94.57
# 3  13.96M  ...                       3.85         24.84                 0.00
# 4  14.42M  ...                       3.87         26.40                 0.00
#
#   ROC (1D) RSI (14 / 1D) STOCH (14 / 1D) STOCHRSI (14 / 1D)  \
# 0     0.87         55.08           53.80              50.31
# 1     3.70         70.91           77.22              80.76
# 2    30.69         74.82           71.95              74.34
# 3    -0.91         57.09           56.36              12.26
# 4    -0.78         56.79           55.49              11.43
#
#   Ultimate Oscillator (14 /1D) Williams %R (1D)  \
# 0                        60.39           -33.52
# 1                        58.73            -0.34
# 2                        65.86           -14.51
# 3                        49.74           -46.30
# 4                        50.87           -45.10
#
#   var columnsSettings_stock_screener = new ColumnsSettings(  'ltr', // strHtmlDir  'resultsContainer', // containerId  'resultsContainer', // tab  'stock_screener', // id  'Currently selected: X (max 8)', // message  '8', // intMaxCheckboxes  '1' // intMinOptCheckboxes \t);  Adjust table  Name  Symbol  Exchange  Sector  Industry  Last  Chg. %  Market Cap  Vol.  P/E Ratio  MACD (12,26 / 1D)  Revenue  Average Vol. (3m)  EPS  Beta  Dividend  Yield  15 Minutes  Hourly  Daily  Weekly  Monthly  Daily  1 Week  1 Month  YTD  1 Year  3 Years  1-Year Change  Dividend Yield (%)  P/E Ratio (TTM)  Price to Sales (TTM)  Price to Cash Flow (MRQ)  Price to Free Cash Flow (TTM)  Price to Book (MRQ)  Price to Tangible Book (MRQ)  EPS(MRQ) vs Qtr. 1 Yr. Ago  EPS(TTM) vs TTM 1 Yr. Ago  5 Year EPS Growth  Sales (MRQ) vs Qtr. 1 Yr. Ago  Sales (TTM) vs TTM 1 Yr. Ago (TTM)  5 Year Sales Growth  5 Year Capital Spending Growth  Asset Turnover (TTM)  Inventory Turnover (TTM)  Revenue/Employee (TTM)  Net Income/Employee (TTM)  Receivable Turnover (TTM)  52 wk Range - High  52 wk Range - Low  % Change from 52 wk High  % Change from 52 wk Low  Previous Month % Change  Gross margin (TTM)  Gross Margin (5YA)  Operating margin (TTM)  Operating margin (5YA)  Pretax margin (TTM)  Pretax margin (5YA)  Net Profit margin (TTM)  Net Profit margin (5YA)  Quick Ratio (MRQ)  Current Ratio (MRQ)  LT Debt to Equity (MRQ)  Total Debt to Equity  Dividend Yield 5 Year Avg. (5YA)  Dividend Growth Rate (ANN)  Payout Ratio (TTM)  ADX (14 / 1D)  ATR (14 / 1D)  Bull/Bear Power (13 / 1D)  CCI (14 / 1D)  Highs/Lows (14 / 1D)  ROC (1D)  RSI (14 / 1D)  STOCH (14 / 1D)  STOCHRSI (14 / 1D)  Ultimate Oscillator (14 /1D)  Williams %R (1D)  Advanced Metrics  Currently selected:  6  (max 8 )  Apply  $('#colSelectPopup_stock_screener').click(function(e) {  e.stopPropagation(); \t});
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 81 columns]

# %%
df_table_select = df_table[0][['Name', 'Symbol', 'Exchange', 'Sector', 'Market Cap']]
df_table_select.head()
# Out:
#          Name Symbol Exchange      Sector Market Cap
# 0   Microsoft   MSFT   NASDAQ  Technology      3.15T
# 1       Apple   AAPL   NASDAQ  Technology      3.02T
# 2      NVIDIA   NVDA   NASDAQ  Technology      2.97T
# 3  Alphabet A  GOOGL   NASDAQ  Technology      2.16T
# 4  Alphabet C   GOOG   NASDAQ  Technology      2.16T

# %%
# count number of pages
end_num = driver.find_element(By.CLASS_NAME, value='js-total-results').text
print(math.ceil(int(end_num) / 50))
# Out:
# 220

# %%
driver.quit()

# %% [markdown]
# ## class for `ticker_global` database

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC 
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
from datetime import datetime
import math
import pandas as pd 
import numpy as np
from tqdm import tqdm
import time
import pymysql
import keyring
import platform


class UpdateTickerGlobalDB():
    
    def __init__(self):
        # # install Chrome driver
        # self.driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

        # US country code = '5'
        self.country_code = '5'


        # # first page URL
        # self.url = f'''https://investing.com/stock-screener/?sp=country::
        # {self.country_code}|sector::a|industry::a|equityType::ORD%3Ceq_market_cap;1'''
        
        # # open page with url
        # self.driver.get(url)
        
    def get_ticker_global_data(self):
        
        # install Chrome driver
        driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

        # first page URL
        url = f'''https://investing.com/stock-screener/?sp=country::
        {self.country_code}|sector::a|industry::a|equityType::ORD%3Ceq_market_cap;1'''
        
        # open page with url
        driver.get(url)
        
        # 'Screener Results'shows after table which contains ticker informations is loaded.
        # Wait until table is loaded using WebDriverWait()
        WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
            (By.XPATH, '//*[@id="resultsTable"]/tbody')
        ))
        
        # Crawl number of tickers and count number of pages
        end_num = driver.find_element(By.CLASS_NAME, value='js-total-results').text
        end_num = math.ceil(int(end_num) / 50)
        
        all_data_df = []
        
        for i in tqdm(range(1, end_num + 1)):
            url = f'''https://investing.com/stock-screener/?sp=country::
                {self.country_code}|sector::a|industry::a|equityType::ORD%3Ceq_market_cap;{i}'''
            driver.get(url)
            
            try:
                WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
                    (By.XPATH, '//*[@id="resultsTable"]/tbody')
                ))
                
            except:
                time.sleep(1)
                driver.refresh()
                WebDriverWait(driver, 10).until(EC.visibility_of_element_located(
                    (By.XPATH, '//*[@id="resultsTable"]/tbody')
                ))
                
            html = BeautifulSoup(driver.page_source, 'lxml')
            html_table = html.select(
                'table.genTbl.openTbl.resultsStockScreenerTbl.elpTbl'
            )
            df_table = pd.read_html(html_table[0].prettify())
            df_table_select = df_table[0][['Name', 'Symbol', 'Exchange', 'Sector', 'Market Cap']]
    
            all_data_df.append(df_table_select)
            
            time.sleep(1)
            
        # concatenate all dataframes after ending loop
        all_data_df_bind = pd.concat(all_data_df, axis=0)
        
        data_country = html.find(class_='js-search-input inputDropDown')['value']
        all_data_df_bind['country'] = data_country
        all_data_df_bind['date'] = datetime.today().strftime('%Y-%m-%d')
        
        # delete row whose name is null
        all_data_df_bind = all_data_df_bind[~all_data_df_bind['Name'].isnull()]
        
        
        # select exchange market which can be traded in
        all_data_df_bind = all_data_df_bind[all_data_df_bind['Exchange'].isin(
            ['NASDAQ', 'NYSE', 'NYSE Amex']
        )]
        
        # drop duplicate
        all_data_df_bind = all_data_df_bind.drop_duplicates(['Symbol'])
        all_data_df_bind.reset_index(inplace=True, drop=True)
        all_data_df_bind = all_data_df_bind.replace({np.nan: None})
        
        driver.quit()
        
        return all_data_df_bind
    
    def update_db_ticker_global(self):
        
        all_data_df_bind = self.get_ticker_global_data()

        # database info
        user = 'root'
        pw = keyring.get_password('macmini_db', user)
        host = '192.168.219.112' if platform.system() == 'Windows' else '127.0.0.1'
        
        con = pymysql.connect(
            user=user,
            passwd=pw,
            host=host,
            db='stock',
            charset='utf8'
        )
        
        mycursor = con.cursor()
        
        query = """
                INSERT INTO ticker_global (name, symbol, exchange, sector, market_cap, country, date)
                VALUES (%s, %s, %s, %s, %s, %s, %s)
                ON DUPLICATE KEY UPDATE
                name=VALUES(name), exchange=VALUES(exchange), sector=VALUES(exchange), market_cap=VALUES(market_cap);
                """
        
        args = all_data_df_bind.values.tolist()
        
        mycursor.executemany(query, args)
        con.commit()
        
        con.close()

# %%
a = UpdateTickerGlobalDB()
a.update_db_ticker_global()
# Out:
# 100%|██████████| 164/164 [08:53<00:00,  3.25s/it]

# %% [markdown]
# ## Class for updating`price_global` database

# %%
import yfinance as yf
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import time
from tqdm import tqdm
import keyring

class UpdatePriceGlobalDB():
    def __init__(self):
        self.user = 'root'
        self.pw = keyring.get_password('macmini_db', self.user)
        self.host = '192.168.219.112' if platform.system() == 'Windows' else '127.0.0.1'
        self.port = 3306
        self.db = 'stock'
        
    def get_ticker_list(self):
        
        # connect DB
        engine = create_engine(f'mysql+pymysql://{self.user}:{self.pw}@{self.host}:{self.port}/{self.db}')

        con = pymysql.connect(
            user=self.user,
            passwd=self.pw,
            host = self.host,
            db=self.db,
            charset='utf8'
        )
        
        mycurosr = con.cursor()
        
        # select ticker list
        ticker_list = pd.read_sql(
            """ 
            SELECT * FROM ticker_global
            WHERE date = (SELECT MAX(date) FROM ticker_global)
            AND country = 'United States';
            """
        , con=engine)
        
        engine.dispose()
        con.close()
        
        return ticker_list
        
    def update_db_price_global(self):
        
        ticker_list = self.get_ticker_list()
        error_list = []
        
        # connect db
        engine = create_engine(f'mysql+pymysql://{self.user}:{self.pw}@{self.host}:{self.port}/{self.db}')

        con = pymysql.connect(
            user=self.user,
            passwd=self.pw,
            host = self.host,
            db=self.db,
            charset='utf8'
        )
        
        mycurosr = con.cursor()
        
        query = """ 
                INSERT INTO price_global (date, high, low, open, close, volume, adj_close, ticker)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                ON DUPLICATE KEY UPDATE
                high=VALUE(high), low=VALUES(low), open=VALUES(open), close=VALUES(close), volume=VALUES(volume), adj_close=VALUES(adj_close);
                """
        
        # download all prices of all tickers
        for i in tqdm(range(0, len(ticker_list))):
            
            # select a ticker
            ticker = ticker_list['symbol'][i]
            
            # if error happens, it will be ignored
            try:
                # download price
                price = yf.download(ticker, progress=False)
                
                # clean data
                price = price.reset_index()
                price['ticker'] = ticker
                
                # insert into DB
                args = price.values.tolist()
                mycurosr.executemany(query, args)
                con.commit()
            
            except:
                print(ticker)
                error_list.append(ticker)
                
            time.sleep(1)
            
        # close the db connection
        engine.dispose()
        con.close()

# %%
a = UpdatePriceGlobalDB()
a.update_db_price_global()
# Out:
#   3%|▎         | 132/5142 [03:44<2:13:52,  1.60s/it]
# 1 Failed download:
# ['AGMA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|█▏        | 587/5142 [16:03<1:54:00,  1.50s/it]
# 1 Failed download:
# ['BFA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  11%|█▏        | 590/5142 [16:07<1:52:41,  1.49s/it]
# 1 Failed download:
# ['BFB']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  12%|█▏        | 629/5142 [17:12<2:17:32,  1.83s/it]
# 1 Failed download:
# ['BIOB']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  13%|█▎        | 694/5142 [18:58<1:44:13,  1.41s/it]
# 1 Failed download:
# ['BNREA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  14%|█▍        | 735/5142 [20:03<2:15:11,  1.84s/it]
# 1 Failed download:
# ['BRKA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  14%|█▍        | 736/5142 [20:04<2:08:27,  1.75s/it]
# 1 Failed download:
# ['BRKB']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  22%|██▏       | 1152/5142 [32:17<1:35:08,  1.43s/it]
# 1 Failed download:
# ['CRDA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1925-07-02 -> 2024-06-08)')
#  25%|██▍       | 1265/5142 [35:40<1:55:30,  1.79s/it]
# 1 Failed download:
# ['CWENA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  30%|██▉       | 1524/5142 [43:27<2:54:08,  2.89s/it]
# 1 Failed download:
# ['ELEP']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  37%|███▋      | 1928/5142 [55:22<2:15:01,  2.52s/it]
# 1 Failed download:
# ['GEFB']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  40%|████      | 2080/5142 [59:37<1:25:07,  1.67s/it]
# 1 Failed download:
# ['GTNA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  42%|████▏     | 2134/5142 [1:01:20<2:10:22,  2.60s/it]
# 1 Failed download:
# ['HEIA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  44%|████▍     | 2256/5142 [1:04:59<1:34:56,  1.97s/it]
# 1 Failed download:
# ['HVTA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  51%|█████▏    | 2638/5142 [1:15:42<1:04:14,  1.54s/it]
# 1 Failed download:
# ['LAC_W']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  52%|█████▏    | 2682/5142 [1:16:58<1:18:10,  1.91s/it]
# 1 Failed download:
# ['LENB']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  52%|█████▏    | 2699/5142 [1:17:23<59:28,  1.46s/it]
# 1 Failed download:
# ['LGFA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  53%|█████▎    | 2700/5142 [1:17:25<58:16,  1.43s/it]
# 1 Failed download:
# ['LGFB']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  54%|█████▍    | 2784/5142 [1:19:47<1:02:47,  1.60s/it]
# 1 Failed download:
# ['LRTX']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  58%|█████▊    | 2968/5142 [1:25:01<1:10:33,  1.95s/it]
# 1 Failed download:
# ['MKCV']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  59%|█████▉    | 3021/5142 [1:26:34<1:01:46,  1.75s/it]
# 1 Failed download:
# ['MOGA']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  59%|█████▉    | 3022/5142 [1:26:36<1:03:15,  1.79s/it]
# 1 Failed download:
# ['MOGB']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  60%|██████    | 3100/5142 [1:28:52<1:12:56,  2.14s/it]
# 1 Failed download:
# ['MTRS']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1925-07-02 -> 2024-06-08)')
#  64%|██████▍   | 3283/5142 [1:34:14<1:41:34,  3.28s/it]
# 1 Failed download:
# ['NTHI']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  70%|███████   | 3608/5142 [1:43:40<39:41,  1.55s/it]
# 1 Failed download:
# ['PHGE_U']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  76%|███████▌  | 3899/5142 [1:51:48<34:35,  1.67s/it]
# 1 Failed download:
# ['RF_PC']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  76%|███████▋  | 3930/5142 [1:52:45<38:23,  1.90s/it]
# 1 Failed download:
# ['RLND']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  86%|████████▋ | 4440/5142 [2:07:15<23:36,  2.02s/it]
# 1 Failed download:
# ['TAPA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1925-07-02 -> 2024-06-08)')
#  87%|████████▋ | 4487/5142 [2:08:32<18:29,  1.69s/it]
# 1 Failed download:
# ['TEM']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1925-07-02 -> 2024-06-08)')
#  92%|█████████▏| 4712/5142 [2:15:15<15:25,  2.15s/it]
# 1 Failed download:
# ['UHALB']: Exception('%ticker%: No timezone found, symbol may be delisted')
#  98%|█████████▊| 5017/5142 [2:24:26<04:45,  2.29s/it]
# 1 Failed download:
# ['WSOB']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 100%|██████████| 5142/5142 [2:27:52<00:00,  1.73s/it]

# %% [markdown]
# ## Class for updating `fs_global` database

# %% [markdown]
# ### Data exploration

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd
from yahooquery import Ticker
import time
from tqdm import tqdm
import numpy as np
import keyring
import platform

class UpdateFsGlobalDB():
    
    def __init__(self):
        self.user = 'root'
        self.pw = keyring.get_password('macmini_db', self.user)
        self.host = '192.168.219.112' if platform.system() == 'Windows' else '127.0.0.1'
        self.port = 3306
        self.db = 'stock'
        
    def get_ticker_list(self):
        
        # connect DB
        engine = create_engine(f'mysql+pymysql://{self.user}:{self.pw}@{self.host}:{self.port}/{self.db}')

        con = pymysql.connect(
            user=self.user,
            passwd=self.pw,
            host = self.host,
            db=self.db,
            charset='utf8'
        )
        
        mycursor = con.cursor()
        
        # select ticker list
        ticker_list = pd.read_sql(
            """ 
            SELECT * FROM ticker_global
            WHERE date = (SELECT MAX(date) FROM ticker_global)
            AND country = 'United States';
            """
        , con=engine)
        
        engine.dispose()
        con.close()
        
        return ticker_list
    
    def update_db_fs_global(self):
        
        # connect DB
        engine = create_engine(f'mysql+pymysql://{self.user}:{self.pw}@{self.host}:{self.port}/{self.db}')

        con = pymysql.connect(
            user=self.user,
            passwd=self.pw,
            host = self.host,
            db=self.db,
            charset='utf8'
        )
        
        mycursor = con.cursor()
        
        ticker_list = self.get_ticker_list()
        error_list = []
        
        query = """ 
                    INSERT INTO fs_global (ticker, date, account, value, freq)
                    VALUES (%s, %s, %s, %s, %s)
                    ON DUPLICATE KEY UPDATE
                    value = VALUES(value);
                """
        
        # connect db
        engine = create_engine(f'mysql+pymysql://{self.user}:{self.pw}@{self.host}:{self.port}/{self.db}')
        
        # download all fs
        for i in tqdm(range(0, len(ticker_list))):
            # select ticker
            ticker = ticker_list['symbol'][i]
            
            try:
                # download data
                data = Ticker(ticker)
                
                # yearly fs
                data_y = data.all_financial_data(frequency='a')
                data_y.reset_index(inplace=True)
                data_y = data_y.loc[:, ~data_y.columns.isin(['periodType', 'currencyCode'])]
                data_y = data_y.melt(id_vars=['symbol', 'asOfDate'])
                data_y = data_y.replace([np.nan], None)
                data_y['freq'] = 'y'
                data_y.columns = ['ticker', 'date', 'account', 'value', 'freq']
                
                # quarterly fs
                data_q = data.all_financial_data(frequency='q')
                data_q.reset_index(inplace=True)
                data_q = data_q.iloc[:, ~data_q.columns.isin(['periodType', 'currencyCode'])]
                data_q = data_q.melt(id_vars=['symbol', 'asOfDate'])
                data_q = data_q.replace([np.nan], None)
                data_q['freq'] = 'q'
                data_q.columns = ['ticer', 'date', 'account', 'value', 'freq']
                
                # concat
                data_fs = pd.concat([data_y, data_q], axis=0)
                
                # insert into db
                args = data_fs.values.tolist()
                mycursor.executemany(query, args)
                con.commit()
                
            except:
                print(ticker)
                error_list.append(ticker)
                
            time.sleep(1)
            
        # close db connection
        engine.dispose()
        con.close()

# %%
a = UpdateFsGlobalDB()
a.update_db_fs_global()
# Out:
#   0%|          | 0/5142 [00:00<?, ?it/s]
# A
#   0%|          | 1/5142 [00:04<5:53:38,  4.13s/it]
# AA
#   0%|          | 2/5142 [00:08<6:07:54,  4.29s/it]
# AACI
#   0%|          | 3/5142 [00:12<5:42:51,  4.00s/it]
# AACT
#   0%|          | 4/5142 [00:16<6:03:01,  4.24s/it]
# AADI
#   0%|          | 5/5142 [00:20<5:47:24,  4.06s/it]
# AAGR
#   0%|          | 6/5142 [00:25<6:06:15,  4.28s/it]
# AAL
#   0%|          | 7/5142 [00:29<6:01:33,  4.22s/it]
# AAMC
#   0%|          | 8/5142 [00:32<5:44:45,  4.03s/it]
# AAME
#   0%|          | 9/5142 [00:36<5:34:09,  3.91s/it]
# AAN
#   0%|          | 10/5142 [00:40<5:47:08,  4.06s/it]
# AAOI
#   0%|          | 11/5142 [00:44<5:42:39,  4.01s/it]
# AAON
#   0%|          | 12/5142 [00:48<5:40:56,  3.99s/it]
# AAP
#   0%|          | 13/5142 [00:52<5:36:41,  3.94s/it]
# AAPL
#   0%|          | 14/5142 [00:56<5:34:39,  3.92s/it]
# ABAT
#   0%|          | 15/5142 [01:00<5:42:39,  4.01s/it]
# ABBV
#   0%|          | 16/5142 [01:04<5:37:09,  3.95s/it]
# ABCB
#   0%|          | 17/5142 [01:08<5:39:26,  3.97s/it]
# ABCL
#   0%|          | 18/5142 [01:12<5:35:31,  3.93s/it]
# ABEO
#   0%|          | 19/5142 [01:17<6:03:45,  4.26s/it]
# ABG
#   0%|          | 20/5142 [01:21<5:56:20,  4.17s/it]
# ABIO
#   0%|          | 21/5142 [01:25<5:45:56,  4.05s/it]
# ABL
#   0%|          | 22/5142 [01:29<5:41:09,  4.00s/it]
# ABLV
#   0%|          | 23/5142 [01:32<5:33:01,  3.90s/it]
# ABM
#   0%|          | 24/5142 [01:37<5:44:06,  4.03s/it]
# ABNB
#   0%|          | 25/5142 [01:41<5:55:38,  4.17s/it]
# ABOS
# CAG
#  16%|█▌        | 823/5142 [56:29<5:08:22,  4.28s/it]
# CAH
#  16%|█▌        | 824/5142 [56:33<5:01:56,  4.20s/it]
# CAKE
#  16%|█▌        | 825/5142 [56:37<4:56:25,  4.12s/it]
# CAL
#  16%|█▌        | 826/5142 [56:42<5:03:13,  4.22s/it]
# CALB
#  16%|█▌        | 827/5142 [56:46<5:07:12,  4.27s/it]
# CALC
#  16%|█▌        | 828/5142 [56:50<5:00:50,  4.18s/it]
# CALM
#  16%|█▌        | 829/5142 [56:55<5:04:53,  4.24s/it]
# CALT
#  16%|█▌        | 830/5142 [56:58<4:51:42,  4.06s/it]
# CALX
#  16%|█▌        | 831/5142 [57:02<4:52:12,  4.07s/it]
# CAMP
#  16%|█▌        | 832/5142 [57:06<4:48:31,  4.02s/it]
# CAMT
#  16%|█▌        | 833/5142 [57:10<4:46:34,  3.99s/it]
# CAN
# ...
# VRN
#  95%|█████████▍| 4870/5142 [5:36:52<18:21,  4.05s/it]
# VRNS
#  95%|█████████▍| 4871/5142 [5:36:56<18:38,  4.13s/it]
# VRNT
#  95%|█████████▍| 4872/5142 [5:37:00<18:21,  4.08s/it]
# VRPX
#  95%|█████████▍| 4873/5142 [5:37:09<25:21,  5.66s/it]
# VRRM
#  95%|█████████▍| 4874/5142 [5:37:14<23:29,  5.26s/it]
# VRSK
#  95%|█████████▍| 4875/5142 [5:37:17<21:26,  4.82s/it]
# VRSN
#  95%|█████████▍| 4876/5142 [5:37:26<26:32,  5.99s/it]
# VRT
#  95%|█████████▍| 4877/5142 [5:37:30<23:45,  5.38s/it]
# VRTS
#  95%|█████████▍| 4878/5142 [5:37:34<22:02,  5.01s/it]
# VRTX
#  95%|█████████▍| 4879/5142 [5:37:38<20:19,  4.64s/it]
# VS
#  95%|█████████▍| 4880/5142 [5:37:42<19:43,  4.52s/it]
# VSAC
#  95%|█████████▍| 4881/5142 [5:37:46<18:27,  4.24s/it]
# VSAT
#  95%|█████████▍| 4882/5142 [5:37:50<18:05,  4.18s/it]
# VSCO
#  95%|█████████▍| 4883/5142 [5:37:54<17:54,  4.15s/it]
# VSEC
#  95%|█████████▍| 4884/5142 [5:37:58<17:39,  4.11s/it]
# VSH
#  95%|█████████▌| 4885/5142 [5:38:02<17:57,  4.19s/it]
# VSME
#  95%|█████████▌| 4886/5142 [5:38:07<19:00,  4.45s/it]
# VST
#  95%|█████████▌| 4887/5142 [5:38:12<19:21,  4.55s/it]
# VSTA
#  95%|█████████▌| 4888/5142 [5:38:16<18:19,  4.33s/it]
# VSTE
#  95%|█████████▌| 4889/5142 [5:38:20<17:27,  4.14s/it]
# VSTM
#  95%|█████████▌| 4890/5142 [5:38:27<21:37,  5.15s/it]
# VSTO
#  95%|█████████▌| 4891/5142 [5:38:31<20:05,  4.80s/it]
# VSTS
#  95%|█████████▌| 4892/5142 [5:38:35<19:02,  4.57s/it]
# VTAK
#  95%|█████████▌| 4893/5142 [5:38:39<18:08,  4.37s/it]
# VTEX
#  95%|█████████▌| 4894/5142 [5:38:43<17:22,  4.20s/it]
# VTGN
#  95%|█████████▌| 4895/5142 [5:38:47<16:45,  4.07s/it]
# VTLE
#  95%|█████████▌| 4896/5142 [5:38:51<16:45,  4.09s/it]
# VTNR
#  95%|█████████▌| 4897/5142 [5:38:55<17:01,  4.17s/it]
# VTOL
#  95%|█████████▌| 4898/5142 [5:38:59<17:11,  4.23s/it]
# VTR
#  95%|█████████▌| 4899/5142 [5:39:04<17:09,  4.24s/it]
# VTRS
#  95%|█████████▌| 4900/5142 [5:39:08<16:47,  4.16s/it]
# VTRU
#  95%|█████████▌| 4901/5142 [5:39:12<16:59,  4.23s/it]
# VTS
#  95%|█████████▌| 4902/5142 [5:39:17<17:42,  4.43s/it]
# VTSI
#  95%|█████████▌| 4903/5142 [5:39:21<17:02,  4.28s/it]
# VTVT
#  95%|█████████▌| 4904/5142 [5:39:25<16:19,  4.11s/it]
# VTYX
#  95%|█████████▌| 4905/5142 [5:39:28<15:43,  3.98s/it]
# VUZI
#  95%|█████████▌| 4906/5142 [5:39:32<15:30,  3.94s/it]
# VVI
#  95%|█████████▌| 4907/5142 [5:39:37<16:00,  4.09s/it]
# VVOS
#  95%|█████████▌| 4908/5142 [5:39:40<15:31,  3.98s/it]
# VVPR
#  95%|█████████▌| 4909/5142 [5:39:44<15:13,  3.92s/it]
# VVV
#  95%|█████████▌| 4910/5142 [5:39:48<15:33,  4.02s/it]
# VVX
#  96%|█████████▌| 4911/5142 [5:39:52<15:18,  3.98s/it]
# VWE
#  96%|█████████▌| 4912/5142 [5:39:57<16:25,  4.29s/it]
# VXRT
#  96%|█████████▌| 4913/5142 [5:40:01<16:01,  4.20s/it]
# VYGR
#  96%|█████████▌| 4914/5142 [5:40:05<15:16,  4.02s/it]
# VYNE
#  96%|█████████▌| 4915/5142 [5:40:09<14:58,  3.96s/it]
# VYX
#  96%|█████████▌| 4916/5142 [5:40:13<15:26,  4.10s/it]
# VZ
#  96%|█████████▌| 4917/5142 [5:40:17<15:10,  4.05s/it]
# VZIO
#  96%|█████████▌| 4918/5142 [5:40:21<14:47,  3.96s/it]
# VZLA
#  96%|█████████▌| 4919/5142 [5:40:25<14:52,  4.00s/it]
# W
#  96%|█████████▌| 4920/5142 [5:40:29<14:39,  3.96s/it]
# WAB
#  96%|█████████▌| 4921/5142 [5:40:33<14:29,  3.93s/it]
# WABC
#  96%|█████████▌| 4922/5142 [5:40:36<14:03,  3.83s/it]
# WAFD
#  96%|█████████▌| 4923/5142 [5:40:40<14:17,  3.92s/it]
# WAFU
#  96%|█████████▌| 4924/5142 [5:40:45<14:35,  4.02s/it]
# WAL
#  96%|█████████▌| 4925/5142 [5:40:48<14:24,  3.98s/it]
# WALD
#  96%|█████████▌| 4926/5142 [5:40:52<13:59,  3.89s/it]
# WASH
#  96%|█████████▌| 4927/5142 [5:40:56<14:03,  3.92s/it]
# WAT
#  96%|█████████▌| 4928/5142 [5:41:00<14:15,  4.00s/it]
# WATT
#  96%|█████████▌| 4929/5142 [5:41:04<13:52,  3.91s/it]
# WAVD
#  96%|█████████▌| 4930/5142 [5:41:08<14:10,  4.01s/it]
# WAVS
#  96%|█████████▌| 4931/5142 [5:41:12<13:42,  3.90s/it]
# WAY
#  96%|█████████▌| 4932/5142 [5:41:16<13:28,  3.85s/it]
# WBA
#  96%|█████████▌| 4933/5142 [5:41:20<13:32,  3.89s/it]
# WBD
#  96%|█████████▌| 4934/5142 [5:41:24<13:35,  3.92s/it]
# WBS
#  96%|█████████▌| 4935/5142 [5:41:28<13:34,  3.93s/it]
# WBUY
#  96%|█████████▌| 4936/5142 [5:41:31<13:22,  3.90s/it]
# WBX
#  96%|█████████▌| 4937/5142 [5:41:35<13:18,  3.90s/it]
# WCC
#  96%|█████████▌| 4938/5142 [5:41:39<13:17,  3.91s/it]
# WCN
#  96%|█████████▌| 4939/5142 [5:41:44<13:43,  4.06s/it]
# WD
#  96%|█████████▌| 4940/5142 [5:41:47<13:26,  3.99s/it]
# WDAY
#  96%|█████████▌| 4941/5142 [5:41:52<13:26,  4.01s/it]
# WDC
#  96%|█████████▌| 4942/5142 [5:41:56<13:37,  4.09s/it]
# WDFC
#  96%|█████████▌| 4943/5142 [5:42:00<13:19,  4.02s/it]
# WEAV
#  96%|█████████▌| 4944/5142 [5:42:03<13:04,  3.96s/it]
# WEC
#  96%|█████████▌| 4945/5142 [5:42:08<13:07,  4.00s/it]
# WEL
#  96%|█████████▌| 4946/5142 [5:42:11<12:43,  3.90s/it]
# WELL
#  96%|█████████▌| 4947/5142 [5:42:15<12:46,  3.93s/it]
# WEN
#  96%|█████████▌| 4948/5142 [5:42:20<13:11,  4.08s/it]
# WERN
#  96%|█████████▌| 4949/5142 [5:42:26<15:28,  4.81s/it]
# WETH
#  96%|█████████▋| 4950/5142 [5:42:31<15:20,  4.79s/it]
# WEX
#  96%|█████████▋| 4951/5142 [5:42:35<14:26,  4.54s/it]
# WEYS
#  96%|█████████▋| 4952/5142 [5:42:39<13:56,  4.40s/it]
# WFC
#  96%|█████████▋| 4953/5142 [5:42:44<14:24,  4.57s/it]
# WFCF
#  96%|█████████▋| 4954/5142 [5:42:48<13:54,  4.44s/it]
# WFG
#  96%|█████████▋| 4955/5142 [5:42:52<13:39,  4.38s/it]
# WFRD
#  96%|█████████▋| 4956/5142 [5:42:57<13:32,  4.37s/it]
# WGO
#  96%|█████████▋| 4957/5142 [5:43:01<13:23,  4.34s/it]
# WGS
#  96%|█████████▋| 4958/5142 [5:43:05<12:50,  4.19s/it]
# WH
#  96%|█████████▋| 4959/5142 [5:43:09<12:29,  4.10s/it]
# WHD
#  96%|█████████▋| 4960/5142 [5:43:12<12:08,  4.00s/it]
# WHF
#  96%|█████████▋| 4961/5142 [5:43:16<11:49,  3.92s/it]
# WHG
#  96%|█████████▋| 4962/5142 [5:43:20<11:54,  3.97s/it]
# WHLM
#  97%|█████████▋| 4963/5142 [5:43:24<11:43,  3.93s/it]
# WHLR
#  97%|█████████▋| 4964/5142 [5:43:29<12:30,  4.21s/it]
# WHR
#  97%|█████████▋| 4965/5142 [5:43:33<12:28,  4.23s/it]
# WILC
#  97%|█████████▋| 4966/5142 [5:43:37<12:27,  4.25s/it]
# WIMI
#  97%|█████████▋| 4967/5142 [5:43:41<11:54,  4.08s/it]
# WINA
#  97%|█████████▋| 4968/5142 [5:43:45<11:39,  4.02s/it]
# WING
#  97%|█████████▋| 4969/5142 [5:43:49<11:20,  3.94s/it]
# WINT
#  97%|█████████▋| 4970/5142 [5:43:53<11:29,  4.01s/it]
# WINV
#  97%|█████████▋| 4971/5142 [5:43:56<10:59,  3.86s/it]
# WIRE
#  97%|█████████▋| 4972/5142 [5:44:00<10:45,  3.80s/it]
# WISA
#  97%|█████████▋| 4973/5142 [5:44:04<10:58,  3.90s/it]
# WIX
#  97%|█████████▋| 4974/5142 [5:44:08<10:53,  3.89s/it]
# WK
#  97%|█████████▋| 4975/5142 [5:44:12<10:55,  3.92s/it]
# WKC
#  97%|█████████▋| 4976/5142 [5:44:17<11:14,  4.06s/it]
# WKHS
#  97%|█████████▋| 4977/5142 [5:44:20<11:01,  4.01s/it]
# WKME
#  97%|█████████▋| 4978/5142 [5:44:24<10:45,  3.94s/it]
# WKSP
#  97%|█████████▋| 4979/5142 [5:44:28<10:40,  3.93s/it]
# WLDN
#  97%|█████████▋| 4980/5142 [5:44:33<11:16,  4.17s/it]
# WLDS
#  97%|█████████▋| 4981/5142 [5:44:37<10:47,  4.02s/it]
# WLFC
#  97%|█████████▋| 4982/5142 [5:44:41<11:07,  4.17s/it]
# WLGS
#  97%|█████████▋| 4983/5142 [5:44:45<11:06,  4.19s/it]
# WLK
#  97%|█████████▋| 4984/5142 [5:44:49<10:55,  4.15s/it]
# WLY
#  97%|█████████▋| 4985/5142 [5:44:56<12:33,  4.80s/it]
# WLYB
#  97%|█████████▋| 4986/5142 [5:45:01<12:36,  4.85s/it]
# WM
#  97%|█████████▋| 4987/5142 [5:45:05<11:57,  4.63s/it]
# WMB
#  97%|█████████▋| 4988/5142 [5:45:09<11:30,  4.48s/it]
# WMG
#  97%|█████████▋| 4989/5142 [5:45:13<10:52,  4.27s/it]
# WMK
#  97%|█████████▋| 4990/5142 [5:45:18<11:23,  4.49s/it]
# WMPN
#  97%|█████████▋| 4991/5142 [5:45:22<11:07,  4.42s/it]
# WMS
#  97%|█████████▋| 4992/5142 [5:45:26<10:48,  4.32s/it]
# WMT
#  97%|█████████▋| 4993/5142 [5:45:30<10:22,  4.18s/it]
# WNC
#  97%|█████████▋| 4994/5142 [5:45:34<10:06,  4.10s/it]
# WNEB
#  97%|█████████▋| 4995/5142 [5:45:38<09:50,  4.02s/it]
# WNW
#  97%|█████████▋| 4996/5142 [5:45:41<09:39,  3.97s/it]
# WOLF
#  97%|█████████▋| 4997/5142 [5:45:46<09:45,  4.04s/it]
# WOOF
#  97%|█████████▋| 4998/5142 [5:45:49<09:33,  3.99s/it]
# WOR
#  97%|█████████▋| 4999/5142 [5:45:54<09:33,  4.01s/it]
# WORX
#  97%|█████████▋| 5000/5142 [5:45:58<09:34,  4.05s/it]
# WOW
#  97%|█████████▋| 5001/5142 [5:46:02<09:50,  4.19s/it]
#  98%|█████████▊| 5037/5142 [5:48:26<07:01,  4.01s/it]
# WWW
#  98%|█████████▊| 5038/5142 [5:48:30<06:53,  3.98s/it]
# WY
#  98%|█████████▊| 5039/5142 [5:48:34<06:55,  4.04s/it]
# WYNN
#  98%|█████████▊| 5040/5142 [5:48:38<06:46,  3.99s/it]
# WYY
#  98%|█████████▊| 5041/5142 [5:48:42<06:46,  4.02s/it]
# X
#  98%|█████████▊| 5042/5142 [5:48:46<06:38,  3.99s/it]
# XAIR
#  98%|█████████▊| 5043/5142 [5:48:50<06:34,  3.98s/it]
# XBIO
#  98%|█████████▊| 5044/5142 [5:48:59<08:50,  5.42s/it]
# XBIT
#  98%|█████████▊| 5045/5142 [5:49:03<08:02,  4.97s/it]
# XBP
#  98%|█████████▊| 5046/5142 [5:49:07<07:29,  4.68s/it]
# XCUR
#  98%|█████████▊| 5047/5142 [5:49:11<07:01,  4.44s/it]
# XEL
#  98%|█████████▊| 5048/5142 [5:49:15<06:42,  4.28s/it]
# XELA
#  98%|█████████▊| 5049/5142 [5:49:20<06:52,  4.44s/it]
# XELB
#  98%|█████████▊| 5050/5142 [5:49:24<06:33,  4.28s/it]
# XENE
#  98%|█████████▊| 5051/5142 [5:49:27<06:18,  4.16s/it]
# XERS
#  98%|█████████▊| 5052/5142 [5:49:31<06:04,  4.05s/it]
# XFIN
#  98%|█████████▊| 5053/5142 [5:49:35<05:46,  3.89s/it]
# XFOR
#  98%|█████████▊| 5054/5142 [5:49:39<05:49,  3.97s/it]
# XGN
#  98%|█████████▊| 5055/5142 [5:49:43<05:42,  3.93s/it]
# XHG
#  98%|█████████▊| 5056/5142 [5:49:46<05:29,  3.83s/it]
# XLO
#  98%|█████████▊| 5057/5142 [5:49:50<05:21,  3.79s/it]
# XMTR
#  98%|█████████▊| 5058/5142 [5:49:55<05:36,  4.01s/it]
# XNCR
#  98%|█████████▊| 5059/5142 [5:49:58<05:31,  3.99s/it]
# XOM
#  98%|█████████▊| 5060/5142 [5:50:03<05:35,  4.10s/it]
# XOMA
#  98%|█████████▊| 5061/5142 [5:50:08<06:01,  4.46s/it]
# XOS
#  98%|█████████▊| 5062/5142 [5:50:12<05:42,  4.28s/it]
# XP
#  98%|█████████▊| 5063/5142 [5:50:16<05:36,  4.26s/it]
# XPEL
#  98%|█████████▊| 5064/5142 [5:50:20<05:21,  4.12s/it]
# XPER
#  99%|█████████▊| 5065/5142 [5:50:24<05:23,  4.20s/it]
# XPEV
#  99%|█████████▊| 5066/5142 [5:50:28<05:12,  4.11s/it]
# XPL
#  99%|█████████▊| 5067/5142 [5:50:32<05:01,  4.02s/it]
# XPO
#  99%|█████████▊| 5068/5142 [5:50:36<04:55,  3.99s/it]
# XPOF
#  99%|█████████▊| 5069/5142 [5:50:40<04:49,  3.96s/it]
# XPON
#  99%|█████████▊| 5070/5142 [5:50:44<04:44,  3.95s/it]
# XPRO
#  99%|█████████▊| 5071/5142 [5:50:48<04:38,  3.92s/it]
# XRAY
#  99%|█████████▊| 5072/5142 [5:50:52<04:39,  4.00s/it]
