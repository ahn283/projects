# %% [markdown]
# # KospiAnalyzer

# %% [markdown]
# ### Get daily stock price

# %%
import module.KospiAnalyzer as ka

ticker = ka.KospiTicker()

naver = ticker.get_daily_price('NAVER', '2018-05-04')
naver.head()
# Out:
# end_date is initialized to '2023-06-17'
#               code        date    open    high     low   close   diff  volume
# date
# 2018-05-04  035420  2018-05-04  725000  735000  717000  717000  10000  102357
# 2018-05-08  035420  2018-05-08  727000  738000  721000  731000  14000   97455
# 2018-05-09  035420  2018-05-09  730000  740000  723000  727000   4000   95131
# 2018-05-10  035420  2018-05-10  730000  735000  718000  720000   7000   83361
# 2018-05-11  035420  2018-05-11  721000  729000  714000  717000   3000  109545

# %% [markdown]
# ### Analyze stocks

# %%
import module.KospiAnalyzer as ka
import pandas as pd

# instantiate
kospi = ka.KospiTicker()

# tickers
tickers = ['삼성전자', '현대자동차', 'NAVER', '카카오', '카카오페이', 'LG화학']

# ticker data frame
data = pd.DataFrame()

# get yesterday analyzed data 
for ticker in tickers:
    data = kospi.analyze_stock(ticker, '2020-01-01')
# Out:
# end_date is initialized to '2023-06-17'
# -----------------
# 삼성전자 yesterday data
# return yesterday:  0.00419580419580412
# volatiltity yesterday:  0.06162721779927465
# Bollinger band percentage yesterday:  0.6904978081552285
# Bollinger band percentage 20 days mean:  0.8857371009477569
# Bollinger band bandwidth:  9.79352566204621
# Bollinger band bandwidth 20 days mean:  12.621818128796253
# end_date is initialized to '2023-06-17'
# -----------------
# 현대자동차 yesterday data
# return yesterday:  -0.001502253380070151
# volatiltity yesterday:  0.05104861560376107
# Bollinger band percentage yesterday:  0.3805754633714125
# Bollinger band percentage 20 days mean:  0.35696185433704697
# Bollinger band bandwidth:  8.00644014362715
# Bollinger band bandwidth 20 days mean:  8.06917686832384
# end_date is initialized to '2023-06-17'
# -----------------
# NAVER yesterday data
# return yesterday:  0.009975062344139696
# volatiltity yesterday:  0.06608443762847922
# Bollinger band percentage yesterday:  0.4020990390764518
# Bollinger band percentage 20 days mean:  0.4124566697291397
# Bollinger band bandwidth:  10.286308631840514
# Bollinger band bandwidth 20 days mean:  14.366664485700507
# end_date is initialized to '2023-06-17'
# -----------------
# 카카오 yesterday data
# return yesterday:  -0.005565862708719838
# volatiltity yesterday:  0.05074393974365496
# Bollinger band percentage yesterday:  -0.1482754282768
# Bollinger band percentage 20 days mean:  0.3595603544449729
# Bollinger band bandwidth:  8.046923005964034
# Bollinger band bandwidth 20 days mean:  5.326144706986814
# end_date is initialized to '2023-06-17'
# -----------------
# 카카오페이 yesterday data
# return yesterday:  0.005586592178770999
# volatiltity yesterday:  0.10244791936907933
# Bollinger band percentage yesterday:  0.10771373047974828
# Bollinger band percentage 20 days mean:  0.5141325307667141
# Bollinger band bandwidth:  11.924573427308669
# Bollinger band bandwidth 20 days mean:  9.455932133328778
# end_date is initialized to '2023-06-17'
# -----------------
# LG화학 yesterday data
# return yesterday:  0.02908587257617734
# volatiltity yesterday:  0.08581379628690221
# Bollinger band percentage yesterday:  0.808329074027507
# Bollinger band percentage 20 days mean:  0.5908773841351993
# Bollinger band bandwidth:  10.569815117308892
# Bollinger band bandwidth 20 days mean:  10.63458068504695

# %% [markdown]
# # KospiCAPM

# %% [markdown]
# ## Get efficient frontier

# %%
import module.KospiCAPM  as kc

tickers = ['삼성전자', '현대자동차', 'NAVER', '카카오', '카카오페이', 'LG화학']
capm = kc.CAPM(tickers, '2020-01-01')
capm_port = capm.get_efficient_frontier(10000)
# Out:
# 2020-01-01
# 2023-06-17
# Return = 0.3036997350268291
# Volatility = 0.36019816501987856

# %% [markdown]
# # PortOptimizerKospi

# %%
import module.PortOptimizerKospi as pok

tickers = ['NAVER', '삼성전자', '현대자동차']
engine = pok.PortOptimizer(tickers, '2020-01-01')

res = engine.run(cs_model='RP', ts_model='VT', cost=0.0005)

# %%
port_weights = res[0]
port_asset_rets = res[1]
port_rets = res[2]
weights_recent = port_weights.iloc[-1].tolist()
print(weights_recent, tickers)
engine.plot_pie_chart(weights_recent, tickers)
engine.performance_analytics(port_weights, port_asset_rets, port_rets, qs_report=True)
# Out:
# [0.2506587128842827, 0.37010141700136967, 0.3792398701143475] ['NAVER', '삼성전자', '현대자동차']

# %% [markdown]
# # Optimizing portfolio with kospi, us stock, dollars and cash

# %% [markdown]
# ### Get portfolio prices

# %%
import module.GetStockPrices as GetStockPrices

# get stock prices
tickers_k = ['삼성전자', '현대자동차', 'NAVER', '카카오', '카카오페이', 'LG화학']
# tickers_k = []
tickers_u = ['AAPL', 'AMZN', 'GOOG', 'TSLA', 'NVDA', 'MSFT']

gsp = GetStockPrices.GetStockPrices(tickers_k, tickers_u, start_date='2021-01-01')

data = gsp.get_portfolio_data()
# Out:
# [*********************100%***********************]  6 of 6 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### optimize portfolio

# %%
import module.PortOptimizer as po
import pandas as pd


engine = po.PortOptimizer(data)

res = engine.run(cs_model='RP', ts_model='VT', cost=0.0005)

# %% [markdown]
# ### Visulaization

# %%
port_weights = res[0]
port_asset_rets = res[1]
port_rets = res[2]
weights_recent = port_weights.iloc[-1]
engine.plot_pie_chart(weights_recent.values, weights_recent.index.tolist())
print(weights_recent)
# Out:
# 삼성전자       0.066672
# 현대자동차      0.082657
# NAVER      0.048745
# 카카오        0.042358
# 카카오페이      0.050912
# LG화학       0.065829
# AAPL       0.080967
# AMZN       0.057555
# GOOG       0.046660
# MSFT       0.058616
# NVDA       0.036208
# TSLA       0.031564
# usd_krw    0.331258
# Name: 2023-06-16, dtype: float64

# %%
engine.performance_analytics(port_weights, port_asset_rets, port_rets, qs_report=True)

# %% [markdown]
# # GetUSIndex

# %%
import module.GetUSIndex as GetUSIndex

data = GetUSIndex.get_index_data()
data
# Out:
# start = ^DJI, dow_jones
# end = ^DJI, dow_jones
# start = ^GSPC, s&p_500
# end = ^GSPC, s&p_500
# start = ^IXIC, nasdaq
# end = ^IXIC, nasdaq
# start = ^RUT, russell_2000
# end = ^RUT, russell_2000
# start = XLK, information_technology
# end = XLK, information_technology
# start = XLV, health_care
# end = XLV, health_care
# start = XLY, consumer_discretionary
# end = XLY, consumer_discretionary
# start = XLP, consumer_staples
# end = XLP, consumer_staples
# start = XLE, energy
# end = XLE, energy
# start = XLF, financials
# end = XLF, financials
# start = XLI, industrials
# end = XLI, industrials
# start = XLB, materials
# end = XLB, materials
# start = XLRE, real_estate
# end = XLRE, real_estate
# start = XLU, utilities
# end = XLU, utilities
#            index_name  code    open     high      low   close    volume  \
# date
# 1992-01-02  dow_jones  ^DJI  3152.1  3172.63  3139.31  3172.4  23550000
# 1992-01-03  dow_jones  ^DJI  3172.4  3210.64  3165.92  3201.5  23620000
# 1992-01-06  dow_jones  ^DJI  3201.5  3213.33  3191.86  3200.1  27280000
# 1992-01-07  dow_jones  ^DJI  3200.1  3210.20  3184.48  3204.8  25510000
# 1992-01-08  dow_jones  ^DJI  3204.8  3229.20  3185.82  3203.9  29040000
#
#             dividends  stock_splits  Capital Gains
# date
# 1992-01-02        0.0           0.0            NaN
# 1992-01-03        0.0           0.0            NaN
# 1992-01-06        0.0           0.0            NaN
# 1992-01-07        0.0           0.0            NaN
# 1992-01-08        0.0           0.0            NaN
#            index_name code   open   high    low  close    volume  dividends  \
# date
# 2023-06-12  utilities  XLU  66.44  66.62  66.00  66.27  11483700        0.0
# 2023-06-13  utilities  XLU  65.87  66.49  65.76  66.26  11868600        0.0
# 2023-06-14  utilities  XLU  66.50  67.01  66.09  66.22  14023600        0.0
# 2023-06-15  utilities  XLU  66.47  67.10  66.33  66.94  13701200        0.0
# 2023-06-16  utilities  XLU  67.10  67.84  67.05  67.30  13685100        0.0
#
#             stock_splits  Capital Gains
# date
# 2023-06-12           0.0            0.0
# 2023-06-13           0.0            0.0
# 2023-06-14           0.0            0.0
# 2023-06-15           0.0            0.0
# 2023-06-16           0.0            0.0
# (111509, 10)
#            index_name  code     open     high      low    close    volume  \
# date
# 1992-01-02  dow_jones  ^DJI  3152.10  3172.63  3139.31  3172.40  23550000
# 1992-01-03  dow_jones  ^DJI  3172.40  3210.64  3165.92  3201.50  23620000
# 1992-01-06  dow_jones  ^DJI  3201.50  3213.33  3191.86  3200.10  27280000
# 1992-01-07  dow_jones  ^DJI  3200.10  3210.20  3184.48  3204.80  25510000
# 1992-01-08  dow_jones  ^DJI  3204.80  3229.20  3185.82  3203.90  29040000
# ...               ...   ...      ...      ...      ...      ...       ...
# 2023-06-12  utilities   XLU    66.44    66.62    66.00    66.27  11483700
# 2023-06-13  utilities   XLU    65.87    66.49    65.76    66.26  11868600
# 2023-06-14  utilities   XLU    66.50    67.01    66.09    66.22  14023600
# 2023-06-15  utilities   XLU    66.47    67.10    66.33    66.94  13701200
# 2023-06-16  utilities   XLU    67.10    67.84    67.05    67.30  13685100
#
#             dividends  stock_splits  Capital Gains
# date
# 1992-01-02        0.0           0.0            NaN
# 1992-01-03        0.0           0.0            NaN
# 1992-01-06        0.0           0.0            NaN
# 1992-01-07        0.0           0.0            NaN
# 1992-01-08        0.0           0.0            NaN
# ...               ...           ...            ...
# 2023-06-12        0.0           0.0            0.0
# 2023-06-13        0.0           0.0            0.0
# 2023-06-14        0.0           0.0            0.0
# 2023-06-15        0.0           0.0            0.0
# 2023-06-16        0.0           0.0            0.0
#
# [111509 rows x 10 columns]
